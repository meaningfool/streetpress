# %% [markdown]
# # Goal & Approach
#
# The goal of this file is to build a unified Knowledge Graph of actors and relationships based on the entities detected in the streetpress_extract_entities.ipynb file.
#
# In that previous extraction steps, entities were extracted from multiple chunks of texts coming from multiple articles. Those entities and relationships were stored in separate files.
#
# The challenge here is to aggregate and resolve all these entities and relationships to build one big graph with as few duplicates as possible.
#
# The resolution relies on 2 components : a full-text search index and a vector search index. And the final source of truth for resolved entities is a Sqlite instance.
#
# <img src="streetpress_resolution.png" width="800" height="480">

# %% [markdown]
# # How to run this file
#
# Required:
# - An OpenAI API key
#
# Your secrets (API keys) must be put in a ".env" file in the same folder as this file.
# The format should be OPENAI_API_KEY = "sk-..." (replace with your own key)

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # Retrieve LLM reponses' data

# %%
# Load entities from disk

import json
import os
import glob

def load_entities_from_file(file_path):
    # Load data from the file
    actors = []
    rels = []
    with open(file_path, 'r') as file:
        data = json.load(file)
        actors = data['actors']
        rels = data['relationships']

    return actors, rels


def get_llm_files_paths(folder_name="llm_responses"):
    folder_path = os.path.join(".", folder_name)

    # Check if the folder exists
    if not os.path.exists(folder_path):
        print(f"Folder not found: {folder_path}")
        return None

    # Pattern to match files of the form 'article-x_chunk-y.json'
    pattern = os.path.join(folder_path, "article-*_chunk-*.json")

    # Find all matching files
    file_paths = glob.glob(pattern)

    return file_paths

# %%
# Test on the first chunk of the first article

file_path = "./llm_responses/article-1_chunk-1.json"
actors, rels = load_entities_from_file(file_path)
print(actors)
print(rels)
# Out:
# [{'id': 'kata_fight_club', 'name': 'Kata fight club', 'label': 'ORGANIZATION', 'key_information': 'It is the name of the underground fight club.'}, {'id': 'gud', 'name': 'Gud', 'label': 'ORGANIZATION', 'key_information': 'It is a right-wing extremist group.'}, {'id': 'generation_identitaire', 'name': 'Génération identitaire', 'label': 'ORGANIZATION', 'key_information': 'It is a right-wing extremist group.'}, {'id': 'zouaves', 'name': 'Zouaves', 'label': 'ORGANIZATION', 'key_information': 'It is a neo-Nazi group.'}, {'id': 'remi_g', 'name': 'Rémi G.', 'label': 'PERSON', 'key_information': 'He is a main participant of the right-wing extremist fight club./nHe attended a prestigious military school./nHe shares his drawings and other content on Instagram and YouTube./nHe is part of the Catholic identitarian movement Academia Christiana.'}, {'id': 'herve_ryssen', 'name': 'Hervé Ryssen', 'label': 'PERSON', 'key_information': 'He is an antisemitic and conspiracist French person whose documentaries Rémi G. shares.'}, {'id': 'marc_de_cacqueray', 'name': 'Marc de Cacqueray', 'label': 'PERSON', 'key_information': 'He is the leader of Gud and a known right-wing extremist.'}, {'id': 'loutres_gang', 'name': 'Loutres Gang', 'label': 'ORGANIZATION', 'key_information': 'It is a group of fighters from the right-wing extremist groups Auctorum and Luminis.'}, {'id': 'auctorum', 'name': 'Auctorum', 'label': 'ORGANIZATION', 'key_information': 'It is a right-wing extremist group.'}, {'id': 'luminis', 'name': 'Luminis', 'label': 'ORGANIZATION', 'key_information': 'It is a right-wing extremist group.'}, {'id': 'academia_christiana', 'name': 'Academia Christiana', 'label': 'ORGANIZATION', 'key_information': 'It is a Catholic identitarian movement that Rémi G. is part of.'}]
# [{'source': 'remi_g', 'target': 'gud', 'label': 'member of', 'rationale': 'Rémi G. is a member of Gud.'}, {'source': 'remi_g', 'target': 'academia_christiana', 'label': 'member of', 'rationale': 'Rémi G. is a member of Academia Christiana.'}, {'source': 'herve_ryssen', 'target': 'remi_g', 'label': 'content shared by', 'rationale': "Hervé Ryssen's documentaries are shared by Rémi G."}, {'source': 'marc_de_cacqueray', 'target': 'gud', 'label': 'leader of', 'rationale': 'Marc de Cacqueray is the leader of Gud.'}, {'source': 'loutres_gang', 'target': 'auctorum', 'label': 'composed of', 'rationale': 'Loutres Gang is composed of members from Auctorum.'}, {'source': 'loutres_gang', 'target': 'luminis', 'label': 'composed of', 'rationale': 'Loutres Gang is composed of members from Luminis.'}]

# %% [markdown]
# # Create the SQLite DB

# %%
# Boilerplate to interact with SQLite

import sqlite3
import os


def create_sqlite_db(db_name='streetpress.db'):
    # Check if the database file exists
    if os.path.exists(db_name):
        # Delete the file
        os.remove(db_name)
    
    # Creates a new db with that name
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Create table with an auto-incrementing primary key
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS actors (
            id INTEGER PRIMARY KEY,
            name TEXT NOT NULL,
            label TEXT NOT NULL,
            key_information TEXT
        )
    ''')

    cursor.execute('''
        CREATE TABLE IF NOT EXISTS relationships (
            id INTEGER PRIMARY KEY,
            source_actor INTEGER,
            target_actor INTEGER,
            label TEXT NOT NULL,
            rationale TEXT,
            FOREIGN KEY (source_actor) REFERENCES actors (id),
            FOREIGN KEY (target_actor) REFERENCES actors (id)
        )
    ''')

    # Commit and close
    conn.commit()
    conn.close()


def insert_actor_sqlite(actor, db_name="streetpress.db"):
    # Connect to the db
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Insert a new row without specifying the ID
    cursor.execute('''
        INSERT INTO actors (name, label, key_information) VALUES (?, ?, ?)
    ''', (actor['name'], actor['label'], actor['key_information']))

    # Retrieve the ID of the newly inserted row
    inserted_row_id = cursor.lastrowid

    # Commit and close
    conn.commit()
    conn.close()

    return inserted_row_id

def insert_relationship_sqlite(rel, actors_id_map, db_name="streetpress.db"):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Insert a new row without specifying the ID
    cursor.execute('''
        INSERT INTO relationships (source_actor, target_actor, label, rationale) VALUES (?, ?, ?, ?)
    ''', (actors_id_map[rel['source']], actors_id_map[rel['target']], rel['label'], rel['rationale']))

    # Retrieve the ID of the newly inserted row
    inserted_row_id = cursor.lastrowid

    # Commit and close
    conn.commit()
    conn.close()

    return inserted_row_id

def display_table_sqlite(table_name, db_name="streetpress.db"):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()    

    query = "SELECT * FROM " + table_name + " LIMIT 10"
    cursor.execute(query)

    # Fetch and print the results
    print(cursor.fetchall())

    # Close the connection
    conn.close()

def get_actor_by_id(actor_id, db_name="streetpress.db"):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    query = "SELECT * FROM actors WHERE id = ?"
    cursor.execute(query, (actor_id,))

    # Fetch and return the result
    result = cursor.fetchone()

    # Close the connection
    conn.close()

    return result

def get_rel_by_id(rel_id, db_name="streetpress.db"):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    query = "SELECT * FROM relationships WHERE id = ?"
    cursor.execute(query, (rel_id,))

    # Fetch and return the result
    result = cursor.fetchone()

    # Close the connection
    conn.close()

    return result

# %%
# Run an example

create_sqlite_db()
actors_id_map = {}
for actor in actors:
    actor_db_id = insert_actor_sqlite(actor)
    actors_id_map[actor['id']] = actor_db_id
for rel in rels:
    insert_relationship_sqlite(rel,actors_id_map)
display_table_sqlite("actors")
# Out:
# [(1, 'Kata fight club', 'ORGANIZATION', 'It is the name of the underground fight club.'), (2, 'Gud', 'ORGANIZATION', 'It is a right-wing extremist group.'), (3, 'Génération identitaire', 'ORGANIZATION', 'It is a right-wing extremist group.'), (4, 'Zouaves', 'ORGANIZATION', 'It is a neo-Nazi group.'), (5, 'Rémi G.', 'PERSON', 'He is a main participant of the right-wing extremist fight club./nHe attended a prestigious military school./nHe shares his drawings and other content on Instagram and YouTube./nHe is part of the Catholic identitarian movement Academia Christiana.'), (6, 'Hervé Ryssen', 'PERSON', 'He is an antisemitic and conspiracist French person whose documentaries Rémi G. shares.'), (7, 'Marc de Cacqueray', 'PERSON', 'He is the leader of Gud and a known right-wing extremist.'), (8, 'Loutres Gang', 'ORGANIZATION', 'It is a group of fighters from the right-wing extremist groups Auctorum and Luminis.'), (9, 'Auctorum', 'ORGANIZATION', 'It is a right-wing extremist group.'), (10, 'Luminis', 'ORGANIZATION', 'It is a right-wing extremist group.')]

# %% [markdown]
# # Create a full-text index with Whoosh

# %% [markdown]
# Observations:
# - The main QueryParser on the "name" works with OR allowing for partial match on groups of words
# - Fuzziness is applied for words that are 4 letters or more
# - Any match (whatever its score) is accepted

# %%
from whoosh.fields import Schema, TEXT, ID
from whoosh.analysis import StandardAnalyzer
from whoosh.index import create_in
from whoosh.qparser import QueryParser, FuzzyTermPlugin, OrGroup
import os.path
import shutil

class FullTextIndex:
    def __init__(self, ft_index_name="streetpress_ft_index"):
        self.schema = Schema(name=TEXT(stored=True, analyzer=StandardAnalyzer()), sqlite_id=ID(stored=True))

        if os.path.exists(ft_index_name):
            shutil.rmtree(ft_index_name)
        os.mkdir(ft_index_name)

        self.index = create_in(ft_index_name, self.schema)
        self.setup_query_parsers()

    def setup_query_parsers(self):
        self.name_qp = QueryParser("name", schema=self.index.schema, group=OrGroup.factory(0.9))
        self.name_qp.add_plugin(FuzzyTermPlugin())
        self.sqlite_id_qp = QueryParser("sqlite_id", schema=self.index.schema)

    def insert_doc(self, entity_name, sqlite_id):
        with self.index.writer() as writer:
            writer.add_document(name=entity_name, sqlite_id=str(sqlite_id))

    def name_search(self, text):
        query_words = text.split()
        combined_query = " OR ".join([f"{word}~" if len(word) > 3 else word for word in query_words])
        q = self.name_qp.parse(combined_query)
        extracted_results = []

        with self.index.searcher() as s:
            results = s.search(q)
            if len(results) > 0:
                extracted_results = [{"name": result['name'], "sqlite_id": result['sqlite_id'], "score": result.score} for result in results]

        return extracted_results

# %%
# Run an example 

create_sqlite_db()
ft_index = FullTextIndex()
actors_id_map = {}
for actor in actors:
    actor_db_id = insert_actor_sqlite(actor)
    ft_index.insert_doc(actor['name'], actor_db_id)
    actors_id_map[actor['id']] = actor_db_id

# %%
with ft_index.index.searcher() as searcher:
    for doc in searcher.documents():
        print(doc)
# Out:
# {'name': 'Academia Christiana', 'sqlite_id': '11'}
# {'name': 'Marc de Cacqueray', 'sqlite_id': '7'}
# {'name': 'Loutres Gang', 'sqlite_id': '8'}
# {'name': 'Auctorum', 'sqlite_id': '9'}
# {'name': 'Luminis', 'sqlite_id': '10'}
# {'name': 'Hervé Ryssen', 'sqlite_id': '6'}
# {'name': 'Kata fight club', 'sqlite_id': '1'}
# {'name': 'Gud', 'sqlite_id': '2'}
# {'name': 'Génération identitaire', 'sqlite_id': '3'}
# {'name': 'Zouaves', 'sqlite_id': '4'}
# {'name': 'Rémi G.', 'sqlite_id': '5'}

# %%
ft_index.name_search("M. de Caqueret")
# Out:
# [{'name': 'Marc de Cacqueray', 'sqlite_id': '7', 'score': 0.0}]

# %% [markdown]
# # Create a vector index with faiss

# %% [markdown]
# Observations:
# - The distance measure used is the Euclidian distance (default with faiss)
# - The maximum distance used is 0.2

# %%
# Initialize the vector store
import faiss
import numpy as np
from langchain.vectorstores import FAISS
from langchain.docstore.in_memory import InMemoryDocstore
from langchain.vectorstores.utils import DistanceStrategy
from langchain.embeddings.openai import OpenAIEmbeddings

class VectorIndex:
    def __init__(self):
        self.embedding_engine = OpenAIEmbeddings()
        sample_embedding = self.embedding_engine.embed_documents(["Sample text"])[0]

        self.vct_index = faiss.IndexFlatL2(len(sample_embedding))
        self.vct_db = FAISS(
            self.embedding_engine,
            self.vct_index,
            InMemoryDocstore(),
            {},
            normalize_L2=False,
            distance_strategy=DistanceStrategy.EUCLIDEAN_DISTANCE
        )

    def insert_doc(self, text, sqlite_id):
        self.vct_db.add_texts([text], [{"sqlite_id": str(sqlite_id)}])

    def search(self, text, MAX_DIST=0.2):
        results = self.vct_db.similarity_search_with_score(text)
        filtered_results = [result[0].metadata['sqlite_id'] for result in results if result[1]< MAX_DIST]

        return filtered_results

# %%
# Run an example

create_sqlite_db()
ft_index = FullTextIndex()
vct_actor_index = VectorIndex()
vct_rel_index = VectorIndex()

actors_id_map = {}
for actor in actors:
    actor_sqlite_id = insert_actor_sqlite(actor)
    ft_index.insert_doc(actor['name'], actor_sqlite_id)
    vct_actor_index.insert_doc(actor['key_information'], actor_sqlite_id)
    actors_id_map[actor['id']] = actor_sqlite_id

for rel in rels:
    rel_sqlite_id = insert_relationship_sqlite(rel, actors_id_map)
    vct_rel_index.insert_doc(rel['rationale'], rel_sqlite_id)

# %%
print(get_actor_by_id(vct_actor_index.search("It is the name of the underground fight club.")[0]))
print(get_actor_by_id(vct_actor_index.search("He is a main participant of the right-wing extremist fight club.")[0]))
# Out:
# (1, 'Kata fight club', 'ORGANIZATION', 'It is the name of the underground fight club.')
# (5, 'Rémi G.', 'PERSON', 'He is a main participant of the right-wing extremist fight club./nHe attended a prestigious military school./nHe shares his drawings and other content on Instagram and YouTube./nHe is part of the Catholic identitarian movement Academia Christiana.')

# %%
print(get_rel_by_id(vct_rel_index.search("Rémi G. is a member of Gud.")[0]))
# Out:
# (1, 5, 2, 'member of', 'Rémi G. is a member of Gud.')

# %% [markdown]
# # Entity resolution

# %% [markdown]
# Observations:
# - Vector search was initially applied on actors' key information if the full-text search came back empty. But it was removed (commented section): the information provided by the LLM was sometimes too succinct, generating false positives.
# - The vector search seams to be letting through quite a few duplicates for the relationships as well. Some tuning or alternative strategies would be needed.

# %%
def process_actor(actor, ft__actor_index, vct_actor_index, actors_id_map):
    ft_actor_search_results = ft__actor_index.name_search(actor['name'])
    vct_actor_search_results = vct_actor_index.search(actor['key_information'])

    if len(ft_actor_search_results)>0:
        resolved_id = ft_actor_search_results[0]['sqlite_id']
        ft_index.insert_doc(actor['name'], resolved_id)
        vct_actor_index.insert_doc(actor['key_information'], resolved_id)
        actors_id_map[actor['id']] = resolved_id
        print(f"RESOLVED, actor not created: {actor} resolved to {get_actor_by_id(resolved_id)}")
    # elif len(vct_actor_search_results)>0:
    #     resolved_id = vct_actor_search_results[0]
    #     ft_index.insert_doc(actor['name'], resolved_id)
    #     vct_actor_index.insert_doc(actor['key_information'], resolved_id)
    #     actors_id_map[actor['id']] = resolved_id
    else:
        actor_db_id = insert_actor_sqlite(actor)
        ft_index.insert_doc(actor['name'], actor_db_id)
        vct_actor_index.insert_doc(actor['key_information'], actor_db_id)
        actors_id_map[actor['id']] = actor_db_id
    
    return actors_id_map

def process_rel(rel, vct_rel_index, actors_id_map):
    endpoints = [actors_id_map[rel['source']], actors_id_map[rel['target']]]
    vct_search_raw_results = vct_rel_index.search(rel['rationale'])
    filtered_vct_search_results = [result for result in vct_search_raw_results if (str(get_rel_by_id(result)[1]) in endpoints and str(get_rel_by_id(result)[2]) in endpoints)]
    if len(filtered_vct_search_results)==0:
        rel_db_id = insert_relationship_sqlite(rel, actors_id_map)
        vct_rel_index.insert_doc(rel['rationale'], rel_db_id)
        return rel_db_id
    else:
        print(f"RESOLVED, rel not created: {rel} resolved to {get_rel_by_id(filtered_vct_search_results[0])}, relationship not created.")

# %%
# Run an example

create_sqlite_db()
ft_actor_index = FullTextIndex()
vct_actor_index = VectorIndex()
vct_rel_index = VectorIndex()

actors_id_map = {}
for actor in actors:
    process_actor(actor, ft_actor_index, vct_actor_index, actors_id_map)

# %%
for rel in rels:
    process_rel(rel, vct_rel_index,actors_id_map)

# %% [markdown]
# # Process all the files

# %%
# Prepare the DB and the indexes

create_sqlite_db()
ft_actor_index = FullTextIndex()
vct_actor_index = VectorIndex()
vct_rel_index = VectorIndex()

# %%
import datetime

# Find all matching files
file_paths = get_llm_files_paths()
print(file_paths)

for file_path in file_paths:
    print(f"FILE: starting to process {file_path}")
    start_time = datetime.datetime.now()
    print(f"Iteration started at {start_time}")
    file_actors, file_rels = load_entities_from_file(file_path)
    print(f"Actors: {file_actors}")
    print(f"Rels: {file_rels}")
    actors_id_map = {}
    
    for actor in file_actors:
        print(f"start to process actor: {actor}")
        process_actor(actor, ft_actor_index, vct_actor_index, actors_id_map)

    for rel in file_rels:
        print(f"start to process rel: {rel}")
        process_rel(rel, vct_rel_index, actors_id_map)

    end_time = datetime.datetime.now()
    duration = end_time - start_time
    print(f"Iteration ended at {end_time}, duration: {duration}")
# Out:
# ['./llm_responses/article-7_chunk-2.json', './llm_responses/article-19_chunk-1.json', './llm_responses/article-2_chunk-1.json', './llm_responses/article-5_chunk-1.json', './llm_responses/article-28_chunk-1.json', './llm_responses/article-39_chunk-2.json', './llm_responses/article-18_chunk-1.json', './llm_responses/article-4_chunk-1.json', './llm_responses/article-29_chunk-1.json', './llm_responses/article-3_chunk-1.json', './llm_responses/article-7_chunk-3.json', './llm_responses/article-23_chunk-1.json', './llm_responses/article-10_chunk-2.json', './llm_responses/article-42_chunk-2.json', './llm_responses/article-17_chunk-2.json', './llm_responses/article-36_chunk-1.json', './llm_responses/article-31_chunk-1.json', './llm_responses/article-34_chunk-2.json', './llm_responses/article-15_chunk-1.json', './llm_responses/article-40_chunk-1.json', './llm_responses/article-12_chunk-1.json', './llm_responses/article-16_chunk-2.json', './llm_responses/article-11_chunk-2.json', './llm_responses/article-30_chunk-1.json', './llm_responses/article-37_chunk-1.json', './llm_responses/article-22_chunk-1.json', './llm_responses/article-25_chunk-1.json', './llm_responses/article-8_chunk-1.json', './llm_responses/article-35_chunk-2.json', './llm_responses/article-32_chunk-2.json', './llm_responses/article-41_chunk-1.json', './llm_responses/article-14_chunk-1.json', './llm_responses/article-27_chunk-2.json', './llm_responses/article-20_chunk-2.json', './llm_responses/article-35_chunk-1.json', './llm_responses/article-13_chunk-2.json', './llm_responses/article-24_chunk-3.json', './llm_responses/article-20_chunk-1.json', './llm_responses/article-16_chunk-1.json', './llm_responses/article-43_chunk-1.json', './llm_responses/article-11_chunk-1.json', './llm_responses/article-21_chunk-1.json', './llm_responses/article-26_chunk-1.json', './llm_responses/article-33_chunk-1.json', './llm_responses/article-34_chunk-1.json', './llm_responses/article-24_chunk-2.json', './llm_responses/article-10_chunk-1.json', './llm_responses/article-42_chunk-1.json', './llm_responses/article-17_chunk-1.json', './llm_responses/article-13_chunk-3.json', './llm_responses/article-29_chunk-2.json', './llm_responses/article-3_chunk-2.json', './llm_responses/article-39_chunk-1.json', './llm_responses/article-1_chunk-1.json', './llm_responses/article-2_chunk-3.json', './llm_responses/article-6_chunk-1.json', './llm_responses/article-2_chunk-2.json', './llm_responses/article-5_chunk-2.json', './llm_responses/article-29_chunk-3.json', './llm_responses/article-38_chunk-1.json']
# FILE: starting to process ./llm_responses/article-7_chunk-2.json
# Iteration started at 2023-12-18 18:02:26.830479
# Actors: [{'id': 'rnj', 'name': 'RNJ', 'label': 'ORGANIZATION', 'key_information': 'The RNJ is a radical youth organization that was relaunched in 2023./nThe RNJ organizes Forums for training and cohesion for its members and sympathizers./nThe RNJ has local sections, each with a responsible person.'}, {'id': 'pierreromain_thionnet', 'name': 'Pierre-Romain Thionnet', 'label': 'PERSON', 'key_information': 'Pierre-Romain Thionnet is the head of the RNJ and the creator of the RNJ Forums./nHe has also held the position of national secretary at the Cocarde.'}, {'id': 'forums_rnj', 'name': 'Forums RNJ', 'label': 'ORGANIZATION', 'key_information': "The RNJ Forums are events for training and cohesion for the movement's militants and sympathizers./nThey feature speakers such as deputies and academics."}, {'id': 'aloys_vojinovic', 'name': 'Aloys Vojinovic', 'label': 'PERSON', 'key_information': 'Aloys Vojinovic is a former member of the Zouaves Paris, a dissolved nazifying group, who attended a talk on the situation in Hungary at an RNJ Forum./nHe is known to some young RN leaders, including parliamentary attaché Luc Lahalle.'}, {'id': 'eyquem_pons', 'name': 'Eyquem Pons', 'label': 'PERSON', 'key_information': 'Eyquem Pons, also known as Etienne Cormier, is a cadre of Generation Identity who also attended a talk on the situation in Hungary at an RNJ Forum.'}, {'id': 'luc_lahalle', 'name': 'Luc Lahalle', 'label': 'PERSON', 'key_information': 'Luc Lahalle is a parliamentary attaché who often attends RNJ Forums and has been photographed with Aloys Vojinovic./nHe is the assistant of RN MEP Catherine Griset.'}, {'id': 'catherine_griset', 'name': 'Catherine Griset', 'label': 'PERSON', 'key_information': 'Catherine Griset is an RN MEP whose assistant is Luc Lahalle.'}, {'id': 'franck_allisio', 'name': 'Franck Allisio', 'label': 'PERSON', 'key_information': 'Franck Allisio is a local deputy who was invited to the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'}, {'id': 'rafael_f', 'name': 'Rafael F.', 'label': 'PERSON', 'key_information': 'Rafael F., also known as the militant pseudonym Raphaël Ayma, is the spokesperson for Tenesoun./nHe attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'}, {'id': 'helios_c', 'name': 'Hélios C.', 'label': 'PERSON', 'key_information': "Hélios C. is a neofascist militant from Tenesoun who regularly hosts political 'spaces' on the social network Twitter-X./nHe attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône."}, {'id': 'nicolas_m', 'name': 'Nicolas M.', 'label': 'PERSON', 'key_information': "Nicolas M. is a militant who has been through the UNI and has been photographed in front of a 'Clément deserves' tag and a Celtic cross with some members of Tenesoun."}, {'id': 'edouard_bina', 'name': 'Édouard Bina', 'label': 'PERSON', 'key_information': 'Édouard Bina is the head of RNJ 74 and a former member of the Cocarde./nHe has also held the position of national secretary at the Cocarde./nHe has been photographed with Sinisha Milinov and Marceluss.'}, {'id': 'sinisha_milinov', 'name': 'Sinisha Milinov', 'label': 'PERSON', 'key_information': 'Sinisha Milinov is a RN candidate in the 2020 municipal elections, a GI militant and then spokesperson for the Remparts./nHe met Édouard Bina at the Cocarde Lyon and has been photographed with him and Marceluss.'}, {'id': 'julien_chmielewski', 'name': 'Julien Chmielewski', 'label': 'PERSON', 'key_information': 'Julien Chmielewski is a former member of the Cocarde, head of RNJ Puy-de-Dôme, and close to Clermont Non Conforme.'}, {'id': 'clement_girard', 'name': 'Clément Girard', 'label': 'PERSON', 'key_information': 'Clément Girard is a very active RN militant in Fréjus and Seyne-sur-Mer, and is seen alongside deputies Frank Giletti and Frédéric Boccaletti./nIn Avignon, he mainly militates with the Action française.'}, {'id': 'frank_giletti', 'name': 'Frank Giletti', 'label': 'PERSON', 'key_information': 'Frank Giletti is  ...
# Rels: [{'source': 'rnj', 'target': 'pierreromain_thionnet', 'label': 'Leader', 'rationale': 'Pierre-Romain Thionnet is the leader of the RNJ.'}, {'source': 'rnj', 'target': 'forums_rnj', 'label': 'Organizer', 'rationale': 'The RNJ organizes the RNJ Forums.'}, {'source': 'pierreromain_thionnet', 'target': 'forums_rnj', 'label': 'Creator', 'rationale': 'Pierre-Romain Thionnet created the RNJ Forums.'}, {'source': 'rnj', 'target': 'aloys_vojinovic', 'label': 'Attendee', 'rationale': 'Aloys Vojinovic attended an RNJ Forum.'}, {'source': 'rnj', 'target': 'eyquem_pons', 'label': 'Attendee', 'rationale': 'Eyquem Pons attended an RNJ Forum.'}, {'source': 'rnj', 'target': 'luc_lahalle', 'label': 'Attendee', 'rationale': 'Luc Lahalle often attends RNJ Forums.'}, {'source': 'luc_lahalle', 'target': 'catherine_griset', 'label': 'Assistant', 'rationale': 'Luc Lahalle is the assistant of Catherine Griset.'}, {'source': 'rnj', 'target': 'franck_allisio', 'label': 'Host', 'rationale': 'The RNJ of Bouches-du-Rhône hosted Franck Allisio for the first Southern Forum.'}, {'source': 'rnj', 'target': 'rafael_f', 'label': 'Attendee', 'rationale': 'Rafael F. attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'}, {'source': 'rnj', 'target': 'helios_c', 'label': 'Attendee', 'rationale': 'Hélios C. attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'}, {'source': 'rnj', 'target': 'nicolas_m', 'label': 'Leader', 'rationale': 'Édouard Bina is the head of RNJ 74.'}, {'source': 'nicolas_m', 'target': 'edouard_bina', 'label': 'Colleague', 'rationale': 'Édouard Bina and Sinisha Milinov met at the Cocarde Lyon.'}, {'source': 'rnj', 'target': 'sinisha_milinov', 'label': 'Leader', 'rationale': 'Julien Chmielewski is the head of RNJ Puy-de-Dôme.'}, {'source': 'julien_chmielewski', 'target': 'clement_girard', 'label': 'Colleague', 'rationale': 'Clément Girard is seen alongside deputies Frank Giletti and Frédéric Boccaletti.'}, {'source': 'julien_chmielewski', 'target': 'frank_giletti', 'label': 'Colleague', 'rationale': 'Clément Girard is seen alongside deputies Frank Giletti and Frédéric Boccaletti.'}]
# start to process actor: {'id': 'rnj', 'name': 'RNJ', 'label': 'ORGANIZATION', 'key_information': 'The RNJ is a radical youth organization that was relaunched in 2023./nThe RNJ organizes Forums for training and cohesion for its members and sympathizers./nThe RNJ has local sections, each with a responsible person.'}
# start to process actor: {'id': 'pierreromain_thionnet', 'name': 'Pierre-Romain Thionnet', 'label': 'PERSON', 'key_information': 'Pierre-Romain Thionnet is the head of the RNJ and the creator of the RNJ Forums./nHe has also held the position of national secretary at the Cocarde.'}
# start to process actor: {'id': 'forums_rnj', 'name': 'Forums RNJ', 'label': 'ORGANIZATION', 'key_information': "The RNJ Forums are events for training and cohesion for the movement's militants and sympathizers./nThey feature speakers such as deputies and academics."}
# RESOLVED, actor not created: {'id': 'forums_rnj', 'name': 'Forums RNJ', 'label': 'ORGANIZATION', 'key_information': "The RNJ Forums are events for training and cohesion for the movement's militants and sympathizers./nThey feature speakers such as deputies and academics."} resolved to (1, 'RNJ', 'ORGANIZATION', 'The RNJ is a radical youth organization that was relaunched in 2023./nThe RNJ organizes Forums for training and cohesion for its members and sympathizers./nThe RNJ has local sections, each with a responsible person.')
# start to process actor: {'id': 'aloys_vojinovic', 'name': 'Aloys Vojinovic', 'label': 'PERSON', 'key_information': 'Aloys Vojinovic is a former member of the Zouaves Paris, a dissolved nazifying group, who attended a talk on the situation in Hungary at an RNJ Forum./nHe is known to some young RN leaders, including parliamentary attaché Luc Lahalle.'}
# start to process actor: {'id': 'eyquem_pons', 'name': 'Eyquem Pons', 'label': 'PERSON', 'key_information': 'Eyquem Pons, also known as Etienne Cormier, is a cadre of Generation Identity who also attended a talk on the situation in Hungary at an RNJ Forum.'}
# start to process actor: {'id': 'luc_lahalle', 'name': 'Luc Lahalle', 'label': 'PERSON', 'key_information': 'Luc Lahalle is a parliamentary attaché who often attends RNJ Forums and has been photographed with Aloys Vojinovic./nHe is the assistant of RN MEP Catherine Griset.'}
# start to process actor: {'id': 'catherine_griset', 'name': 'Catherine Griset', 'label': 'PERSON', 'key_information': 'Catherine Griset is an RN MEP whose assistant is Luc Lahalle.'}
# start to process actor: {'id': 'franck_allisio', 'name': 'Franck Allisio', 'label': 'PERSON', 'key_information': 'Franck Allisio is a local deputy who was invited to the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'}
# start to process actor: {'id': 'rafael_f', 'name': 'Rafael F.', 'label': 'PERSON', 'key_information': 'Rafael F., also known as the militant pseudonym Raphaël Ayma, is the spokesperson for Tenesoun./nHe attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'}
# start to process actor: {'id': 'helios_c', 'name': 'Hélios C.', 'label': 'PERSON', 'key_information': "Hélios C. is a neofascist militant from Tenesoun who regularly hosts political 'spaces' on the social network Twitter-X./nHe attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône."}
# start to process actor: {'id': 'nicolas_m', 'name': 'Nicolas M.', 'label': 'PERSON', 'key_information': "Nicolas M. is a militant who has been through the UNI and has been photographed in front of a 'Clément deserves' tag and a Celtic cross with some members of Tenesoun."}
# start to process actor: {'id': 'edouard_bina', 'name': 'Édouard Bina', 'label': 'PERSON', 'key_information': 'Édouard Bina is the head of RNJ 74 and a former member of the Cocarde./nHe has also held the position of national secretary at the Cocarde./nHe has been photographed with Sinisha Milinov and Marceluss.'}
# start to process actor: {'id': 'sinisha_milinov', 'name': 'Sinisha Milinov', 'label': 'PERSON', 'key_information': 'Sinisha Milinov is a RN candidate in the 2020 municipal elections, a GI militant and then spokesperson for the Remparts./nHe met Édouard Bina at the Cocarde Lyon and has been photographed with him and Marceluss.'}
# start to process actor: {'id': 'julien_chmielewski', 'name': 'Julien Chmielewski', 'label': 'PERSON', 'key_information': 'Julien Chmielewski is a former member of the Cocarde, head of RNJ Puy-de-Dôme, and close to Clermont Non Conforme.'}
# start to process actor: {'id': 'clement_girard', 'name': 'Clément Girard', 'label': 'PERSON', 'key_information': 'Clément Girard is a very active RN militant in Fréjus and Seyne-sur-Mer, and is seen alongside deputies Frank Giletti and Frédéric Boccaletti./nIn Avignon, he mainly militates with the Action française.'}
# start to process actor: {'id': 'frank_giletti', 'name': 'Frank Giletti', 'label': 'PERSON', 'key_information': 'Frank Giletti is an RN deputy who is seen alongside RN militant Clément Girard.'}
# RESOLVED, actor not created: {'id': 'frank_giletti', 'name': 'Frank Giletti', 'label': 'PERSON', 'key_information': 'Frank Giletti is an RN deputy who is seen alongside RN militant Clément Girard.'} resolved to (7, 'Franck Allisio', 'PERSON', 'Franck Allisio is a local deputy who was invited to the first Southern Forum organized by the RNJ of Bouches-du-Rhône.')
# start to process actor: {'id': 'frederic_boccaletti', 'name': 'Frédéric Boccaletti', 'label': 'PERSON', 'key_information': 'Frédéric Boccaletti is an RN deputy who is seen alongside RN militant Clément Girard.'}
# start to process rel: {'source': 'rnj', 'target': 'pierreromain_thionnet', 'label': 'Leader', 'rationale': 'Pierre-Romain Thionnet is the leader of the RNJ.'}
# start to process rel: {'source': 'rnj', 'target': 'forums_rnj', 'label': 'Organizer', 'rationale': 'The RNJ organizes the RNJ Forums.'}
# start to process rel: {'source': 'pierreromain_thionnet', 'target': 'forums_rnj', 'label': 'Creator', 'rationale': 'Pierre-Romain Thionnet created the RNJ Forums.'}
# RESOLVED, rel not created: {'source': 'pierreromain_thionnet', 'target': 'forums_rnj', 'label': 'Creator', 'rationale': 'Pierre-Romain Thionnet created the RNJ Forums.'} resolved to (2, 1, 1, 'Organizer', 'The RNJ organizes the RNJ Forums.'), relationship not created.
# start to process rel: {'source': 'rnj', 'target': 'aloys_vojinovic', 'label': 'Attendee', 'rationale': 'Aloys Vojinovic attended an RNJ Forum.'}
# start to process rel: {'source': 'rnj', 'target': 'eyquem_pons', 'label': 'Attendee', 'rationale': 'Eyquem Pons attended an RNJ Forum.'}
# start to process rel: {'source': 'rnj', 'target': 'luc_lahalle', 'label': 'Attendee', 'rationale': 'Luc Lahalle often attends RNJ Forums.'}
# start to process rel: {'source': 'luc_lahalle', 'target': 'catherine_griset', 'label': 'Assistant', 'rationale': 'Luc Lahalle is the assistant of Catherine Griset.'}
# start to process rel: {'source': 'rnj', 'target': 'franck_allisio', 'label': 'Host', 'rationale': 'The RNJ of Bouches-du-Rhône hosted Franck Allisio for the first Southern Forum.'}
# start to process rel: {'source': 'rnj', 'target': 'rafael_f', 'label': 'Attendee', 'rationale': 'Rafael F. attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'}
# start to process rel: {'source': 'rnj', 'target': 'helios_c', 'label': 'Attendee', 'rationale': 'Hélios C. attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'}
# start to process rel: {'source': 'rnj', 'target': 'nicolas_m', 'label': 'Leader', 'rationale': 'Édouard Bina is the head of RNJ 74.'}
# start to process rel: {'source': 'nicolas_m', 'target': 'edouard_bina', 'label': 'Colleague', 'rationale': 'Édouard Bina and Sinisha Milinov met at the Cocarde Lyon.'}
# start to process rel: {'source': 'rnj', 'target': 'sinisha_milinov', 'label': 'Leader', 'rationale': 'Julien Chmielewski is the head of RNJ Puy-de-Dôme.'}
# start to process rel: {'source': 'julien_chmielewski', 'target': 'clement_girard', 'label': 'Colleague', 'rationale': 'Clément Girard is seen alongside deputies Frank Giletti and Frédéric Boccaletti.'}
# start to process rel: {'source': 'julien_chmielewski', 'target': 'frank_giletti', 'label': 'Colleague', 'rationale': 'Clément Girard is seen alongside deputies Frank Giletti and Frédéric Boccaletti.'}
# Iteration ended at 2023-12-18 18:02:45.827374, duration: 0:00:18.996895
# FILE: starting to process ./llm_responses/article-19_chunk-1.json
# Iteration started at 2023-12-18 18:02:45.828582
# Actors: [{'id': 'pierre_t', 'name': 'Pierre T.', 'label': 'PERSON', 'key_information': 'Pierre T. is an engineer who organized an undeclared public demonstration./nHe was tried at the Tribunal d’Annecy for this action./nHe had to resign from his job because of his involvement in the demonstration.'}, {'id': 'gud', 'name': 'Gud', 'label': 'ORGANIZATION', 'key_information': 'Gud is a violent student union whose slogan was chanted at the demonstration.'}, {'id': 'franck_cuter', 'name': 'Franck Cuter', 'label': 'PERSON', 'key_information': 'Franck Cuter is a person identified by StreetPress as a participant in the demonstration./nHe is known for his participation in the neo-fascist group Bastion social in Chambéry.'}, {'id': 'francois_delagrande', 'name': 'François Delagrande', 'label': 'PERSON', 'key_information': 'François Delagrande is another person identified by StreetPress as a participant in the demonstration./nHe is known for his participation in the neo-fascist group Bastion social in Chambéry.'}, {'id': 'bastion_social', 'name': 'Bastion social', 'label': 'ORGANIZATION', 'key_information': 'Bastion social is a neo-fascist group that Franck Cuter and François Delagrande were part of./nIt was dissolved by the government in 2019.'}, {'id': 'edelweiss', 'name': 'Edelweiss', 'label': 'ORGANIZATION', 'key_information': 'Edelweiss is a group that served as a base for Bastion social Chambéry and that resurfaced after its dissolution.'}, {'id': 'bastien_c', 'name': 'Bastien C.', 'label': 'PERSON', 'key_information': 'Bastien C. is another far-right militant identified by StreetPress.'}]
# Rels: [{'source': 'franck_cuter', 'target': 'bastion_social', 'label': 'participated in', 'rationale': 'Franck Cuter participated in the neo-fascist group Bastion social.'}, {'source': 'francois_delagrande', 'target': 'bastion_social', 'label': 'participated in', 'rationale': 'François Delagrande participated in the neo-fascist group Bastion social.'}]
# start to process actor: {'id': 'pierre_t', 'name': 'Pierre T.', 'label': 'PERSON', 'key_information': 'Pierre T. is an engineer who organized an undeclared public demonstration./nHe was tried at the Tribunal d’Annecy for this action./nHe had to resign from his job because of his involvement in the demonstration.'}
# RESOLVED, actor not created: {'id': 'pierre_t', 'name': 'Pierre T.', 'label': 'PERSON', 'key_information': 'Pierre T. is an engineer who organized an undeclared public demonstration./nHe was tried at the Tribunal d’Annecy for this action./nHe had to resign from his job because of his involvement in the demonstration.'} resolved to (2, 'Pierre-Romain Thionnet', 'PERSON', 'Pierre-Romain Thionnet is the head of the RNJ and the creator of the RNJ Forums./nHe has also held the position of national secretary at the Cocarde.')
# start to process actor: {'id': 'gud', 'name': 'Gud', 'label': 'ORGANIZATION', 'key_information': 'Gud is a violent student union whose slogan was chanted at the demonstration.'}
# start to process actor: {'id': 'franck_cuter', 'name': 'Franck Cuter', 'label': 'PERSON', 'key_information': 'Franck Cuter is a person identified by StreetPress as a participant in the demonstration./nHe is known for his participation in the neo-fascist group Bastion social in Chambéry.'}
# RESOLVED, actor not created: {'id': 'franck_cuter', 'name': 'Franck Cuter', 'label': 'PERSON', 'key_information': 'Franck Cuter is a person identified by StreetPress as a participant in the demonstration./nHe is known for his participation in the neo-fascist group Bastion social in Chambéry.'} resolved to (7, 'Franck Allisio', 'PERSON', 'Franck Allisio is a local deputy who was invited to the first Southern Forum organized by the RNJ of Bouches-du-Rhône.')
# start to process actor: {'id': 'francois_delagrande', 'name': 'François Delagrande', 'label': 'PERSON', 'key_information': 'François Delagrande is another person identified by StreetPress as a participant in the demonstration./nHe is known for his participation in the neo-fascist group Bastion social in Chambéry.'}
# start to process actor: {'id': 'bastion_social', 'name': 'Bastion social', 'label': 'ORGANIZATION', 'key_information': 'Bastion social is a neo-fascist group that Franck Cuter and François Delagrande were part of./nIt was dissolved by the government in 2019.'}
# start to process actor: {'id': 'edelweiss', 'name': 'Edelweiss', 'label': 'ORGANIZATION', 'key_information': 'Edelweiss is a group that served as a base for Bastion social Chambéry and that resurfaced after its dissolution.'}
# start to process actor: {'id': 'bastien_c', 'name': 'Bastien C.', 'label': 'PERSON', 'key_information': 'Bastien C. is another far-right militant identified by StreetPress.'}
# RESOLVED, actor not created: {'id': 'bastien_c', 'name': 'Bastien C.', 'label': 'PERSON', 'key_information': 'Bastien C. is another far-right militant identified by StreetPress.'} resolved to (18, 'Bastion social', 'ORGANIZATION', 'Bastion social is a neo-fascist group that Franck Cuter and François Delagrande were part of./nIt was dissolved by the government in 2019.')
# start to process rel: {'source': 'franck_cuter', 'target': 'bastion_social', 'label': 'participated in', 'rationale': 'Franck Cuter participated in the neo-fascist group Bastion social.'}
# start to process rel: {'source': 'francois_delagrande', 'target': 'bastion_social', 'label': 'participated in', 'rationale': 'François Delagrande participated in the neo-fascist group Bastion social.'}
# Iteration ended at 2023-12-18 18:02:51.509635, duration: 0:00:05.681053
# FILE: starting to process ./llm_responses/article-2_chunk-1.json
# Iteration started at 2023-12-18 18:02:51.509844
# Actors: [{'id': 'pierre_c', 'name': 'Pierre C.', 'label': 'PERSON', 'key_information': 'Pierre C. is a 17-year-old high school student who was arrested for participating in a ratonnade attempt./nHe is a member of the Martel division./nHe was punished by his mother who forbade him to go out.'}, {'id': 'martel_division', 'name': 'Martel division', 'label': 'ORGANIZATION', 'key_information': "The Martel division is a far-right group composed of about twenty minors or very young adults, mainly in Île-de-France./nThey have been involved in violent actions against children of Maghrebian origin or left-wing activists./nThey have been seen in various cities in France, including Rouen and Besançon./nThey have a Telegram group called 'Don't touch my WP', for White Power."}, {'id': 'antoine_c', 'name': 'Antoine C.', 'label': 'PERSON', 'key_information': 'Antoine C. is a member of the Martel division who is a fan of Brazilian jiu-jitsu.'}, {'id': 'mathis_d', 'name': 'Mathis D.', 'label': 'PERSON', 'key_information': 'Mathis D. is a member of the Martel division.'}, {'id': 'leo_r', 'name': 'Léo R.', 'label': 'PERSON', 'key_information': 'Léo R. is a former soldier and member of the Martel division who chose a book from the Hitler Youth as his bedside book./nHe was arrested at the same time as Pierre C. after the ratonnade attempt before the France-Morocco match./nHe admires Hitler and owns several Nazi flags and armbands.'}, {'id': 'elie_i', 'name': 'Elie I.', 'label': 'PERSON', 'key_information': "Elie I. is the driver of the Martel division, despite being only 16 years old and not having a driver's license."}, {'id': 'vandal_besak', 'name': 'Vandal Besak', 'label': 'ORGANIZATION', 'key_information': 'The Vandal Besak is a violent far-right movement that has been seen with the Martel division in Besançon.'}, {'id': 'korrigans_squad', 'name': 'Korrigans Squad', 'label': 'ORGANIZATION', 'key_information': 'The Korrigans Squad is a violent far-right movement that has been seen with the Martel division in Besançon.'}, {'id': 'marc_de_cacquerayvalmenier', 'name': 'Marc de Cacqueray-Valmenier', 'label': 'PERSON', 'key_information': 'Marc de Cacqueray-Valmenier is a leader of the Parisian movement who was embarrassed by the erratic behavior of the Martel division, as reported by Mediapart.'}]
# Rels: [{'source': 'pierre_c', 'target': 'martel_division', 'label': 'member of', 'rationale': 'Pierre C. is a member of the Martel division.'}, {'source': 'martel_division', 'target': 'pierre_c', 'label': 'has member', 'rationale': 'The Martel division has Pierre C. as a member.'}, {'source': 'martel_division', 'target': 'antoine_c', 'label': 'has member', 'rationale': 'The Martel division has Antoine C. as a member.'}, {'source': 'martel_division', 'target': 'mathis_d', 'label': 'has member', 'rationale': 'The Martel division has Mathis D. as a member.'}, {'source': 'martel_division', 'target': 'leo_r', 'label': 'has member', 'rationale': 'The Martel division has Léo R. as a member.'}, {'source': 'martel_division', 'target': 'elie_i', 'label': 'has member', 'rationale': 'The Martel division has Elie I. as a member.'}, {'source': 'martel_division', 'target': 'vandal_besak', 'label': 'associated with', 'rationale': 'The Martel division has been seen with the Vandal Besak in Besançon.'}, {'source': 'martel_division', 'target': 'korrigans_squad', 'label': 'associated with', 'rationale': 'The Martel division has been seen with the Korrigans Squad in Besançon.'}, {'source': 'martel_division', 'target': 'marc_de_cacquerayvalmenier', 'label': 'caused embarrassment to', 'rationale': 'The erratic behavior of the Martel division caused embarrassment to Marc de Cacqueray-Valmenier.'}]
# start to process actor: {'id': 'pierre_c', 'name': 'Pierre C.', 'label': 'PERSON', 'key_information': 'Pierre C. is a 17-year-old high school student who was arrested for participating in a ratonnade attempt./nHe is a member of the Martel division./nHe was punished by his mother who forbade him to go out.'}
# RESOLVED, actor not created: {'id': 'pierre_c', 'name': 'Pierre C.', 'label': 'PERSON', 'key_information': 'Pierre C. is a 17-year-old high school student who was arrested for participating in a ratonnade attempt./nHe is a member of the Martel division./nHe was punished by his mother who forbade him to go out.'} resolved to (2, 'Pierre-Romain Thionnet', 'PERSON', 'Pierre-Romain Thionnet is the head of the RNJ and the creator of the RNJ Forums./nHe has also held the position of national secretary at the Cocarde.')
# start to process actor: {'id': 'martel_division', 'name': 'Martel division', 'label': 'ORGANIZATION', 'key_information': "The Martel division is a far-right group composed of about twenty minors or very young adults, mainly in Île-de-France./nThey have been involved in violent actions against children of Maghrebian origin or left-wing activists./nThey have been seen in various cities in France, including Rouen and Besançon./nThey have a Telegram group called 'Don't touch my WP', for White Power."}
# start to process actor: {'id': 'antoine_c', 'name': 'Antoine C.', 'label': 'PERSON', 'key_information': 'Antoine C. is a member of the Martel division who is a fan of Brazilian jiu-jitsu.'}
# start to process actor: {'id': 'mathis_d', 'name': 'Mathis D.', 'label': 'PERSON', 'key_information': 'Mathis D. is a member of the Martel division.'}
# start to process actor: {'id': 'leo_r', 'name': 'Léo R.', 'label': 'PERSON', 'key_information': 'Léo R. is a former soldier and member of the Martel division who chose a book from the Hitler Youth as his bedside book./nHe was arrested at the same time as Pierre C. after the ratonnade attempt before the France-Morocco match./nHe admires Hitler and owns several Nazi flags and armbands.'}
# start to process actor: {'id': 'elie_i', 'name': 'Elie I.', 'label': 'PERSON', 'key_information': "Elie I. is the driver of the Martel division, despite being only 16 years old and not having a driver's license."}
# start to process actor: {'id': 'vandal_besak', 'name': 'Vandal Besak', 'label': 'ORGANIZATION', 'key_information': 'The Vandal Besak is a violent far-right movement that has been seen with the Martel division in Besançon.'}
# start to process actor: {'id': 'korrigans_squad', 'name': 'Korrigans Squad', 'label': 'ORGANIZATION', 'key_information': 'The Korrigans Squad is a violent far-right movement that has been seen with the Martel division in Besançon.'}
# start to process actor: {'id': 'marc_de_cacquerayvalmenier', 'name': 'Marc de Cacqueray-Valmenier', 'label': 'PERSON', 'key_information': 'Marc de Cacqueray-Valmenier is a leader of the Parisian movement who was embarrassed by the erratic behavior of the Martel division, as reported by Mediapart.'}
# start to process rel: {'source': 'pierre_c', 'target': 'martel_division', 'label': 'member of', 'rationale': 'Pierre C. is a member of the Martel division.'}
# start to process rel: {'source': 'martel_division', 'target': 'pierre_c', 'label': 'has member', 'rationale': 'The Martel division has Pierre C. as a member.'}
# start to process rel: {'source': 'martel_division', 'target': 'antoine_c', 'label': 'has member', 'rationale': 'The Martel division has Antoine C. as a member.'}
# start to process rel: {'source': 'martel_division', 'target': 'mathis_d', 'label': 'has member', 'rationale': 'The Martel division has Mathis D. as a member.'}
# start to process rel: {'source': 'martel_division', 'target': 'leo_r', 'label': 'has member', 'rationale': 'The Martel division has Léo R. as a member.'}
# start to process rel: {'source': 'martel_division', 'target': 'elie_i', 'label': 'has member', 'rationale': 'The Martel division has Elie I. as a member.'}
# start to process rel: {'source': 'martel_division', 'target': 'vandal_besak', 'label': 'associated with', 'rationale': 'The Martel division has been seen with the Vandal Besak in Besançon.'}
# start to process rel: {'source': 'martel_division', 'target': 'korrigans_squad', 'label': 'associated with', 'rationale': 'The Martel division has been seen with the Korrigans Squad in Besançon.'}
# start to process rel: {'source': 'martel_division', 'target': 'marc_de_cacquerayvalmenier', 'label': 'caused embarrassment to', 'rationale': 'The erratic behavior of the Martel division caused embarrassment to Marc de Cacqueray-Valmenier.'}
# Iteration ended at 2023-12-18 18:03:00.808067, duration: 0:00:09.298223
# FILE: starting to process ./llm_responses/article-5_chunk-1.json
# Iteration started at 2023-12-18 18:03:00.808281
# Actors: [{'id': 'jeaneudes_gannat', 'name': 'Jean-Eudes Gannat', 'label': 'PERSON', 'key_information': 'Former leader of the Alvarium group/nPresident of the Mouvement Chouan/nWants to increase pressure on the system/nWants to multiply and politicize demonstrations in French cities'}, {'id': 'alvarium', 'name': 'Alvarium', 'label': 'ORGANIZATION', 'key_information': 'Group led by Jean-Eudes Gannat/nDissolved by the government in 2021'}, {'id': 'mouvement_chouan', 'name': 'Mouvement Chouan', 'label': 'ORGANIZATION', 'key_information': 'Group led by Jean-Eudes Gannat'}, {'id': 'raphael_ayma', 'name': 'Raphaël Ayma', 'label': 'PERSON', 'key_information': 'Member of the Tenesoun group/nModerated the discussion on Twitter-X'}, {'id': 'tenesoun', 'name': 'Tenesoun', 'label': 'ORGANIZATION', 'key_information': 'Group that Raphaël Ayma is a part of'}, {'id': 'argos', 'name': 'Argos', 'label': 'ORGANIZATION', 'key_information': 'Represented in the Twitter-X discussion'}, {'id': 'french_lives_matter', 'name': 'French lives matter', 'label': 'ORGANIZATION', 'key_information': 'Represented in the Twitter-X discussion'}, {'id': 'rassemblement_national', 'name': 'Rassemblement national', 'label': 'ORGANIZATION', 'key_information': 'Represented in the Twitter-X discussion'}, {'id': 'edouard_bina', 'name': 'Edouard Bina', 'label': 'PERSON', 'key_information': 'Boss of the Rassemblement national de la jeunesse/nGeneral secretary of the Cocarde union/nHas neo-Nazi affiliations'}, {'id': 'rassemblement_national_de_la_jeunesse', 'name': 'Rassemblement national de la jeunesse', 'label': 'ORGANIZATION', 'key_information': 'Group led by Edouard Bina'}, {'id': 'cocarde', 'name': 'Cocarde', 'label': 'ORGANIZATION', 'key_information': 'Union where Edouard Bina is the general secretary'}, {'id': 'nina_azamberti', 'name': 'Nina Azamberti', 'label': 'PERSON', 'key_information': 'Parliamentary assistant/nCampaigns for Némésis and Defends Marseille'}, {'id': 'nemesis', 'name': 'Némésis', 'label': 'ORGANIZATION', 'key_information': 'Group that Nina Azamberti campaigns for'}, {'id': 'defends_marseille', 'name': 'Defends Marseille', 'label': 'ORGANIZATION', 'key_information': 'Group that Nina Azamberti campaigns for'}, {'id': 'stephane_ravier', 'name': 'Stéphane Ravier', 'label': 'PERSON', 'key_information': 'Senator from Reconquête/nWas present at a gathering in Aix-en-Provence'}, {'id': 'gud', 'name': 'Gud', 'label': 'ORGANIZATION', 'key_information': 'Members performed Kühnen salutes at the rally at the Panthéon'}, {'id': 'natifs', 'name': 'Natifs', 'label': 'ORGANIZATION', 'key_information': 'Represented at the rally at the Panthéon'}, {'id': 'nationalistes_revolutionnaires', 'name': 'Nationalistes révolutionnaires', 'label': 'ORGANIZATION', 'key_information': 'Absent from the Twitter-X discussion/nCriticized by other groups'}, {'id': 'generation_identitaire', 'name': 'Génération identitaire', 'label': 'ORGANIZATION', 'key_information': 'Accused by the nationalistes révolutionnaires of focusing on Islamophobia rather than a general rejection of immigration'}, {'id': 'christian_bouchet', 'name': 'Christian Bouchet', 'label': 'PERSON', 'key_information': 'Leading figure in the nationalistes révolutionnaires/nCriticizes other groups'}]
# Rels: [{'source': 'jeaneudes_gannat', 'target': 'alvarium', 'label': 'Former leader', 'rationale': 'Jean-Eudes Gannat was the former leader of the Alvarium group.'}, {'source': 'jeaneudes_gannat', 'target': 'mouvement_chouan', 'label': 'Current leader', 'rationale': 'Jean-Eudes Gannat is the current leader of the Mouvement Chouan.'}, {'source': 'raphael_ayma', 'target': 'tenesoun', 'label': 'Member', 'rationale': 'Raphaël Ayma is a member of the Tenesoun group.'}, {'source': 'edouard_bina', 'target': 'nemesis', 'label': 'Boss', 'rationale': 'Edouard Bina is the boss of the Rassemblement national de la jeunesse.'}, {'source': 'nina_azamberti', 'target': 'gud', 'label': 'Campaigner', 'rationale': 'Nina Azamberti campaigns for Némésis.'}, {'source': 'nina_azamberti', 'target': 'natifs', 'label': 'Campaigner', 'rationale': 'Nina Azamberti campaigns for Defends Marseille.'}, {'source': 'christian_bouchet', 'target': 'nationalistes_revolutionnaires', 'label': 'Leading figure', 'rationale': 'Christian Bouchet is a leading figure in the nationalistes révolutionnaires.'}]
# start to process actor: {'id': 'jeaneudes_gannat', 'name': 'Jean-Eudes Gannat', 'label': 'PERSON', 'key_information': 'Former leader of the Alvarium group/nPresident of the Mouvement Chouan/nWants to increase pressure on the system/nWants to multiply and politicize demonstrations in French cities'}
# start to process actor: {'id': 'alvarium', 'name': 'Alvarium', 'label': 'ORGANIZATION', 'key_information': 'Group led by Jean-Eudes Gannat/nDissolved by the government in 2021'}
# start to process actor: {'id': 'mouvement_chouan', 'name': 'Mouvement Chouan', 'label': 'ORGANIZATION', 'key_information': 'Group led by Jean-Eudes Gannat'}
# start to process actor: {'id': 'raphael_ayma', 'name': 'Raphaël Ayma', 'label': 'PERSON', 'key_information': 'Member of the Tenesoun group/nModerated the discussion on Twitter-X'}
# start to process actor: {'id': 'tenesoun', 'name': 'Tenesoun', 'label': 'ORGANIZATION', 'key_information': 'Group that Raphaël Ayma is a part of'}
# start to process actor: {'id': 'argos', 'name': 'Argos', 'label': 'ORGANIZATION', 'key_information': 'Represented in the Twitter-X discussion'}
# start to process actor: {'id': 'french_lives_matter', 'name': 'French lives matter', 'label': 'ORGANIZATION', 'key_information': 'Represented in the Twitter-X discussion'}
# start to process actor: {'id': 'rassemblement_national', 'name': 'Rassemblement national', 'label': 'ORGANIZATION', 'key_information': 'Represented in the Twitter-X discussion'}
# start to process actor: {'id': 'edouard_bina', 'name': 'Edouard Bina', 'label': 'PERSON', 'key_information': 'Boss of the Rassemblement national de la jeunesse/nGeneral secretary of the Cocarde union/nHas neo-Nazi affiliations'}
# RESOLVED, actor not created: {'id': 'edouard_bina', 'name': 'Edouard Bina', 'label': 'PERSON', 'key_information': 'Boss of the Rassemblement national de la jeunesse/nGeneral secretary of the Cocarde union/nHas neo-Nazi affiliations'} resolved to (11, 'Édouard Bina', 'PERSON', 'Édouard Bina is the head of RNJ 74 and a former member of the Cocarde./nHe has also held the position of national secretary at the Cocarde./nHe has been photographed with Sinisha Milinov and Marceluss.')
# start to process actor: {'id': 'rassemblement_national_de_la_jeunesse', 'name': 'Rassemblement national de la jeunesse', 'label': 'ORGANIZATION', 'key_information': 'Group led by Edouard Bina'}
# RESOLVED, actor not created: {'id': 'rassemblement_national_de_la_jeunesse', 'name': 'Rassemblement national de la jeunesse', 'label': 'ORGANIZATION', 'key_information': 'Group led by Edouard Bina'} resolved to (35, 'Rassemblement national', 'ORGANIZATION', 'Represented in the Twitter-X discussion')
# start to process actor: {'id': 'cocarde', 'name': 'Cocarde', 'label': 'ORGANIZATION', 'key_information': 'Union where Edouard Bina is the general secretary'}
# start to process actor: {'id': 'nina_azamberti', 'name': 'Nina Azamberti', 'label': 'PERSON', 'key_information': 'Parliamentary assistant/nCampaigns for Némésis and Defends Marseille'}
# RESOLVED, actor not created: {'id': 'nina_azamberti', 'name': 'Nina Azamberti', 'label': 'PERSON', 'key_information': 'Parliamentary assistant/nCampaigns for Némésis and Defends Marseille'} resolved to (11, 'Édouard Bina', 'PERSON', 'Édouard Bina is the head of RNJ 74 and a former member of the Cocarde./nHe has also held the position of national secretary at the Cocarde./nHe has been photographed with Sinisha Milinov and Marceluss.')
# start to process actor: {'id': 'nemesis', 'name': 'Némésis', 'label': 'ORGANIZATION', 'key_information': 'Group that Nina Azamberti campaigns for'}
# start to process actor: {'id': 'defends_marseille', 'name': 'Defends Marseille', 'label': 'ORGANIZATION', 'key_information': 'Group that Nina Azamberti campaigns for'}
# start to process actor: {'id': 'stephane_ravier', 'name': 'Stéphane Ravier', 'label': 'PERSON', 'key_information': 'Senator from Reconquête/nWas present at a gathering in Aix-en-Provence'}
# start to process actor: {'id': 'gud', 'name': 'Gud', 'label': 'ORGANIZATION', 'key_information': 'Members performed Kühnen salutes at the rally at the Panthéon'}
# RESOLVED, actor not created: {'id': 'gud', 'name': 'Gud', 'label': 'ORGANIZATION', 'key_information': 'Members performed Kühnen salutes at the rally at the Panthéon'} resolved to (16, 'Gud', 'ORGANIZATION', 'Gud is a violent student union whose slogan was chanted at the demonstration.')
# start to process actor: {'id': 'natifs', 'name': 'Natifs', 'label': 'ORGANIZATION', 'key_information': 'Represented at the rally at the Panthéon'}
# start to process actor: {'id': 'nationalistes_revolutionnaires', 'name': 'Nationalistes révolutionnaires', 'label': 'ORGANIZATION', 'key_information': 'Absent from the Twitter-X discussion/nCriticized by other groups'}
# start to process actor: {'id': 'generation_identitaire', 'name': 'Génération identitaire', 'label': 'ORGANIZATION', 'key_information': 'Accused by the nationalistes révolutionnaires of focusing on Islamophobia rather than a general rejection of immigration'}
# start to process actor: {'id': 'christian_bouchet', 'name': 'Christian Bouchet', 'label': 'PERSON', 'key_information': 'Leading figure in the nationalistes révolutionnaires/nCriticizes other groups'}
# start to process rel: {'source': 'jeaneudes_gannat', 'target': 'alvarium', 'label': 'Former leader', 'rationale': 'Jean-Eudes Gannat was the former leader of the Alvarium group.'}
# start to process rel: {'source': 'jeaneudes_gannat', 'target': 'mouvement_chouan', 'label': 'Current leader', 'rationale': 'Jean-Eudes Gannat is the current leader of the Mouvement Chouan.'}
# start to process rel: {'source': 'raphael_ayma', 'target': 'tenesoun', 'label': 'Member', 'rationale': 'Raphaël Ayma is a member of the Tenesoun group.'}
# start to process rel: {'source': 'edouard_bina', 'target': 'nemesis', 'label': 'Boss', 'rationale': 'Edouard Bina is the boss of the Rassemblement national de la jeunesse.'}
# start to process rel: {'source': 'nina_azamberti', 'target': 'gud', 'label': 'Campaigner', 'rationale': 'Nina Azamberti campaigns for Némésis.'}
# start to process rel: {'source': 'nina_azamberti', 'target': 'natifs', 'label': 'Campaigner', 'rationale': 'Nina Azamberti campaigns for Defends Marseille.'}
# start to process rel: {'source': 'christian_bouchet', 'target': 'nationalistes_revolutionnaires', 'label': 'Leading figure', 'rationale': 'Christian Bouchet is a leading figure in the nationalistes révolutionnaires.'}
# Iteration ended at 2023-12-18 18:03:21.508765, duration: 0:00:20.700484
# FILE: starting to process ./llm_responses/article-28_chunk-1.json
# Iteration started at 2023-12-18 18:03:21.509121
# Actors: [{'id': 'dominique_delawarde', 'name': 'Dominique Delawarde', 'label': 'PERSON', 'key_information': 'Expressed support for the Syrian government/nAccused of antisemitism/nSigned a reactionary op-ed in Valeurs Actuelles/nAppeared on Sama TV, Cnews, and ERFM/nInvestigated by the parquet de Paris'}]
# Rels: []
# start to process actor: {'id': 'dominique_delawarde', 'name': 'Dominique Delawarde', 'label': 'PERSON', 'key_information': 'Expressed support for the Syrian government/nAccused of antisemitism/nSigned a reactionary op-ed in Valeurs Actuelles/nAppeared on Sama TV, Cnews, and ERFM/nInvestigated by the parquet de Paris'}
# Iteration ended at 2023-12-18 18:03:22.054493, duration: 0:00:00.545372
# FILE: starting to process ./llm_responses/article-39_chunk-2.json
# Iteration started at 2023-12-18 18:03:22.054709
# Actors: [{'id': 'gud', 'name': 'Gud', 'label': 'ORGANIZATION', 'key_information': "The Gud is a group of at least fifty violent neo-Nazis./nThe Gud has been active in Paris, especially at universities such as Assas, Science Po Paris, and La Sorbonne./nThe Gud distributes tracts that call for a 'response' against the 'gauchist vermin' and claim a nationalist-revolutionary ideology./nThe Gud has been reactivated four months ago and its members have participated in three far-right demonstrations and six leafleting actions."}, {'id': 'marc_de_cacquerayvalmenier', 'name': 'Marc de Cacqueray-Valménier', 'label': 'PERSON', 'key_information': "Marc de Cacqueray-Valménier is a member of the Gud./nHe is known for his participation in the Gud's actions and for his disregard for his judicial control."}, {'id': 'chatillon', 'name': 'Châtillon', 'label': 'PERSON', 'key_information': 'Châtillon is a former leader of the Gud./nHe is associated with Marine Le Pen.'}, {'id': 'loustau', 'name': 'Loustau', 'label': 'PERSON', 'key_information': 'Loustau is a former leader of the Gud./nHe is associated with Marine Le Pen.'}, {'id': 'marine_le_pen', 'name': 'Marine Le Pen', 'label': 'PERSON', 'key_information': 'Marine Le Pen is a political figure associated with Châtillon and Loustau.'}]
# Rels: [{'source': 'gud', 'target': 'marc_de_cacquerayvalmenier', 'label': 'includes', 'rationale': 'The Gud includes Marc de Cacqueray-Valménier.'}, {'source': 'gud', 'target': 'chatillon', 'label': 'was led by', 'rationale': 'The Gud was led by Châtillon.'}, {'source': 'gud', 'target': 'loustau', 'label': 'was led by', 'rationale': 'The Gud was led by Loustau.'}, {'source': 'chatillon', 'target': 'marine_le_pen', 'label': 'is associated with', 'rationale': 'Châtillon is associated with Marine Le Pen.'}, {'source': 'loustau', 'target': 'marine_le_pen', 'label': 'is associated with', 'rationale': 'Loustau is associated with Marine Le Pen.'}]
# start to process actor: {'id': 'gud', 'name': 'Gud', 'label': 'ORGANIZATION', 'key_information': "The Gud is a group of at least fifty violent neo-Nazis./nThe Gud has been active in Paris, especially at universities such as Assas, Science Po Paris, and La Sorbonne./nThe Gud distributes tracts that call for a 'response' against the 'gauchist vermin' and claim a nationalist-revolutionary ideology./nThe Gud has been reactivated four months ago and its members have participated in three far-right demonstrations and six leafleting actions."}
# RESOLVED, actor not created: {'id': 'gud', 'name': 'Gud', 'label': 'ORGANIZATION', 'key_information': "The Gud is a group of at least fifty violent neo-Nazis./nThe Gud has been active in Paris, especially at universities such as Assas, Science Po Paris, and La Sorbonne./nThe Gud distributes tracts that call for a 'response' against the 'gauchist vermin' and claim a nationalist-revolutionary ideology./nThe Gud has been reactivated four months ago and its members have participated in three far-right demonstrations and six leafleting actions."} resolved to (16, 'Gud', 'ORGANIZATION', 'Gud is a violent student union whose slogan was chanted at the demonstration.')
# start to process actor: {'id': 'marc_de_cacquerayvalmenier', 'name': 'Marc de Cacqueray-Valménier', 'label': 'PERSON', 'key_information': "Marc de Cacqueray-Valménier is a member of the Gud./nHe is known for his participation in the Gud's actions and for his disregard for his judicial control."}
# RESOLVED, actor not created: {'id': 'marc_de_cacquerayvalmenier', 'name': 'Marc de Cacqueray-Valménier', 'label': 'PERSON', 'key_information': "Marc de Cacqueray-Valménier is a member of the Gud./nHe is known for his participation in the Gud's actions and for his disregard for his judicial control."} resolved to (27, 'Marc de Cacqueray-Valmenier', 'PERSON', 'Marc de Cacqueray-Valmenier is a leader of the Parisian movement who was embarrassed by the erratic behavior of the Martel division, as reported by Mediapart.')
# start to process actor: {'id': 'chatillon', 'name': 'Châtillon', 'label': 'PERSON', 'key_information': 'Châtillon is a former leader of the Gud./nHe is associated with Marine Le Pen.'}
# start to process actor: {'id': 'loustau', 'name': 'Loustau', 'label': 'PERSON', 'key_information': 'Loustau is a former leader of the Gud./nHe is associated with Marine Le Pen.'}
# start to process actor: {'id': 'marine_le_pen', 'name': 'Marine Le Pen', 'label': 'PERSON', 'key_information': 'Marine Le Pen is a political figure associated with Châtillon and Loustau.'}
# start to process rel: {'source': 'gud', 'target': 'marc_de_cacquerayvalmenier', 'label': 'includes', 'rationale': 'The Gud includes Marc de Cacqueray-Valménier.'}
# ...
# RESOLVED, actor not created: {'id': 'tristan_c', 'name': 'Tristan C.', 'label': 'PERSON', 'key_information': "Tristan C. is one of the older heads of the DM./nHe has said on recruitments that he doesn't want a passive green plant."} resolved to (142, 'Tristan Conchon', 'PERSON', 'Tristan Conchon is the treasurer of the Lyon section of Bastion Social./nTristan Conchon founded Audace.')
# start to process actor: {'id': 'auctorum', 'name': 'Auctorum', 'label': 'ORGANIZATION', 'key_information': "Auctorum is a far-right group with which the division Martel participated in a 'sports stage'."}
# RESOLVED, actor not created: {'id': 'auctorum', 'name': 'Auctorum', 'label': 'ORGANIZATION', 'key_information': "Auctorum is a far-right group with which the division Martel participated in a 'sports stage'."} resolved to (173, 'Auctorum', 'ORGANIZATION', 'Participates in combat training sessions with Gud Paris')
# start to process actor: {'id': 'luminis', 'name': 'Luminis', 'label': 'ORGANIZATION', 'key_information': "Luminis is a far-right group with which the division Martel participated in a 'sports stage'."}
# RESOLVED, actor not created: {'id': 'luminis', 'name': 'Luminis', 'label': 'ORGANIZATION', 'key_information': "Luminis is a far-right group with which the division Martel participated in a 'sports stage'."} resolved to (172, 'Luminis', 'ORGANIZATION', 'Participates in combat training sessions with Gud Paris')
# start to process actor: {'id': 'marc_de_cacquerayvalmenier', 'name': 'Marc de Cacqueray-Valmenier', 'label': 'PERSON', 'key_information': 'Marc de Cacqueray-Valmenier is the leader of the Gud and a neonazi leader in Paris.'}
# RESOLVED, actor not created: {'id': 'marc_de_cacquerayvalmenier', 'name': 'Marc de Cacqueray-Valmenier', 'label': 'PERSON', 'key_information': 'Marc de Cacqueray-Valmenier is the leader of the Gud and a neonazi leader in Paris.'} resolved to (27, 'Marc de Cacqueray-Valmenier', 'PERSON', 'Marc de Cacqueray-Valmenier is a leader of the Parisian movement who was embarrassed by the erratic behavior of the Martel division, as reported by Mediapart.')
# start to process actor: {'id': 'antoine', 'name': 'Antoine', 'label': 'PERSON', 'key_information': 'Antoine is one of the minors of the division Martel who was then 17 years old.'}
# RESOLVED, actor not created: {'id': 'antoine', 'name': 'Antoine', 'label': 'PERSON', 'key_information': 'Antoine is one of the minors of the division Martel who was then 17 years old.'} resolved to (21, 'Antoine C.', 'PERSON', 'Antoine C. is a member of the Martel division who is a fan of Brazilian jiu-jitsu.')
# start to process actor: {'id': 'jeunesse_boulogne', 'name': 'Jeunesse Boulogne', 'label': 'ORGANIZATION', 'key_information': 'Jeunesse Boulogne is a group of neonazi hooligans with whom the members of the division Martel hang out.'}
# RESOLVED, actor not created: {'id': 'jeunesse_boulogne', 'name': 'Jeunesse Boulogne', 'label': 'ORGANIZATION', 'key_information': 'Jeunesse Boulogne is a group of neonazi hooligans with whom the members of the division Martel hang out.'} resolved to (41, 'Nationalistes révolutionnaires', 'ORGANIZATION', 'Absent from the Twitter-X discussion/nCriticized by other groups')
# start to process actor: {'id': 'mesos_reims', 'name': 'MesOs Reims', 'label': 'ORGANIZATION', 'key_information': 'MesOs Reims is a group of neonazi hooligans with whom the members of the division Martel hang out.'}
# RESOLVED, actor not created: {'id': 'mesos_reims', 'name': 'MesOs Reims', 'label': 'ORGANIZATION', 'key_information': 'MesOs Reims is a group of neonazi hooligans with whom the members of the division Martel hang out.'} resolved to (70, 'MesOs', 'ORGANIZATION', 'MesOs is a neo-Nazi hooligan group based in Reims, involved in several RNJ poster sessions.')
# start to process actor: {'id': 'pierre_c', 'name': 'Pierre C.', 'label': 'PERSON', 'key_information': 'Pierre C. is a member of the division Martel who preferred to go to the far-right rally the same day against foreigners in Saint-Brévin./nHe published a report after the attack on the Victor Hugo high school in the common group between the DM and the Gud.'}
# RESOLVED, actor not created: {'id': 'pierre_c', 'name': 'Pierre C.', 'label': 'PERSON', 'key_information': 'Pierre C. is a member of the division Martel who preferred to go to the far-right rally the same day against foreigners in Saint-Brévin./nHe published a report after the attack on the Victor Hugo high school in the common group between the DM and the Gud.'} resolved to (2, 'Pierre-Romain Thionnet', 'PERSON', 'Pierre-Romain Thionnet is the head of the RNJ and the creator of the RNJ Forums./nHe has also held the position of national secretary at the Cocarde.')
# start to process actor: {'id': 'elie_i', 'name': 'Elie I.', 'label': 'PERSON', 'key_information': 'Elie I. is a member of the division Martel who preferred to go to the far-right rally the same day against foreigners in Saint-Brévin.'}
# RESOLVED, actor not created: {'id': 'elie_i', 'name': 'Elie I.', 'label': 'PERSON', 'key_information': 'Elie I. is a member of the division Martel who preferred to go to the far-right rally the same day against foreigners in Saint-Brévin.'} resolved to (24, 'Elie I.', 'PERSON', "Elie I. is the driver of the Martel division, despite being only 16 years old and not having a driver's license.")
# start to process rel: {'source': 'division_martel', 'target': 'gud', 'label': 'is guided by', 'rationale': 'The division Martel is guided by the Gud.'}
# start to process rel: {'source': 'gud', 'target': 'zouaves_paris', 'label': 'was reactivated by', 'rationale': 'The Gud was reactivated by the Zouaves Paris.'}
# RESOLVED, rel not created: {'source': 'gud', 'target': 'zouaves_paris', 'label': 'was reactivated by', 'rationale': 'The Gud was reactivated by the Zouaves Paris.'} resolved to (259, 16, 90, 'Succession', 'Zouaves Paris emerged from the dissolution of Gud Paris.'), relationship not created.
# start to process rel: {'source': 'division_martel', 'target': 'freres_kleber', 'label': 'is a member of', 'rationale': 'The Kléber brothers are members of the Gud.'}
# start to process rel: {'source': 'division_martel', 'target': 'hugo_vidal', 'label': 'is a member of', 'rationale': 'Hugo Vidal is a member of the Gud.'}
# start to process rel: {'source': 'division_martel', 'target': 'mathis_d', 'label': 'is a member of', 'rationale': 'Mathis D. is a member of the division Martel and the Gud.'}
# RESOLVED, rel not created: {'source': 'division_martel', 'target': 'mathis_d', 'label': 'is a member of', 'rationale': 'Mathis D. is a member of the division Martel and the Gud.'} resolved to (20, 20, 22, 'has member', 'The Martel division has Mathis D. as a member.'), relationship not created.
# start to process rel: {'source': 'division_martel', 'target': 'leo_r', 'label': 'is a member of', 'rationale': 'Léo R. is a member of the division Martel.'}
# RESOLVED, rel not created: {'source': 'division_martel', 'target': 'leo_r', 'label': 'is a member of', 'rationale': 'Léo R. is a member of the division Martel.'} resolved to (21, 20, 23, 'has member', 'The Martel division has Léo R. as a member.'), relationship not created.
# start to process rel: {'source': 'division_martel', 'target': 'pierre', 'label': 'is a member of', 'rationale': 'Pierre is a member of the division Martel.'}
# RESOLVED, rel not created: {'source': 'division_martel', 'target': 'pierre', 'label': 'is a member of', 'rationale': 'Pierre is a member of the division Martel.'} resolved to (17, 2, 20, 'member of', 'Pierre C. is a member of the Martel division.'), relationship not created.
# start to process rel: {'source': 'division_martel', 'target': 'tristan_c', 'label': 'is a member of', 'rationale': 'Tristan C. is a member of the division Martel.'}
# start to process rel: {'source': 'division_martel', 'target': 'auctorum', 'label': "participated in a 'sports stage' with", 'rationale': "The division Martel participated in a 'sports stage' with Auctorum."}
# start to process rel: {'source': 'division_martel', 'target': 'luminis', 'label': "participated in a 'sports stage' with", 'rationale': "The division Martel participated in a 'sports stage' with Luminis."}
# start to process rel: {'source': 'gud', 'target': 'marc_de_cacquerayvalmenier', 'label': 'is led by', 'rationale': 'The Gud is led by Marc de Cacqueray-Valmenier.'}
# RESOLVED, rel not created: {'source': 'gud', 'target': 'marc_de_cacquerayvalmenier', 'label': 'is led by', 'rationale': 'The Gud is led by Marc de Cacqueray-Valmenier.'} resolved to (33, 16, 27, 'includes', 'The Gud includes Marc de Cacqueray-Valménier.'), relationship not created.
# start to process rel: {'source': 'division_martel', 'target': 'antoine', 'label': 'is a member of', 'rationale': 'Antoine is a member of the division Martel.'}
# RESOLVED, rel not created: {'source': 'division_martel', 'target': 'antoine', 'label': 'is a member of', 'rationale': 'Antoine is a member of the division Martel.'} resolved to (19, 20, 21, 'has member', 'The Martel division has Antoine C. as a member.'), relationship not created.
# start to process rel: {'source': 'division_martel', 'target': 'jeunesse_boulogne', 'label': 'hangs out with', 'rationale': 'The division Martel hangs out with Jeunesse Boulogne.'}
# start to process rel: {'source': 'division_martel', 'target': 'mesos_reims', 'label': 'hangs out with', 'rationale': 'The division Martel hangs out with MesOs Reims.'}
# start to process rel: {'source': 'division_martel', 'target': 'pierre_c', 'label': 'is a member of', 'rationale': 'Pierre C. is a member of the division Martel.'}
# RESOLVED, rel not created: {'source': 'division_martel', 'target': 'pierre_c', 'label': 'is a member of', 'rationale': 'Pierre C. is a member of the division Martel.'} resolved to (17, 2, 20, 'member of', 'Pierre C. is a member of the Martel division.'), relationship not created.
# start to process rel: {'source': 'division_martel', 'target': 'elie_i', 'label': 'is a member of', 'rationale': 'Elie I. is a member of the division Martel.'}
# RESOLVED, rel not created: {'source': 'division_martel', 'target': 'elie_i', 'label': 'is a member of', 'rationale': 'Elie I. is a member of the division Martel.'} resolved to (22, 20, 24, 'has member', 'The Martel division has Elie I. as a member.'), relationship not created.
# Iteration ended at 2023-12-18 18:11:08.329013, duration: 0:00:33.945839
# FILE: starting to process ./llm_responses/article-5_chunk-2.json
# Iteration started at 2023-12-18 18:11:08.329152
# Actors: []
# Rels: []
# Iteration ended at 2023-12-18 18:11:08.330625, duration: 0:00:00.001473
# FILE: starting to process ./llm_responses/article-29_chunk-3.json
# Iteration started at 2023-12-18 18:11:08.330638
# Actors: []
# Rels: []
# Iteration ended at 2023-12-18 18:11:08.330964, duration: 0:00:00.000326
# FILE: starting to process ./llm_responses/article-38_chunk-1.json
# Iteration started at 2023-12-18 18:11:08.330973
# Actors: [{'id': 'elie_hatem', 'name': 'Elie Hatem', 'label': 'PERSON', 'key_information': 'Traveled to Moscow for the same event./nClose associate of Jean-Marie Le Pen./nDefended Bob Denard and Rifaat Al-Assad./nLeft Action Française to found a rival royalist group./nAdvised Boutros Boutros-Ghali./nHas connections in several countries./nHas a photo with Emmanuel Macron.'}, {'id': 'jeanmarie_le_pen', 'name': 'Jean-Marie Le Pen', 'label': 'PERSON', 'key_information': 'Close associate of Elie Hatem.'}, {'id': 'action_francaise', 'name': 'Action Française', 'label': 'ORGANIZATION', 'key_information': 'Elie Hatem left this group to found a rival royalist group.'}, {'id': 'konstantin_malofeev', 'name': 'Konstantin Malofeev', 'label': 'PERSON', 'key_information': "Oligarch behind Marine Le Pen's Russian loans./nPosed with Elie Hatem."}, {'id': 'marine_le_pen', 'name': 'Marine Le Pen', 'label': 'PERSON', 'key_information': 'Received Russian loans from Konstantin Malofeev.'}]
# Rels: [{'source': 'elie_hatem', 'target': 'jeanmarie_le_pen', 'label': 'Associate of', 'rationale': 'Elie Hatem is a close associate of Jean-Marie Le Pen.'}, {'source': 'elie_hatem', 'target': 'action_francaise', 'label': 'Left', 'rationale': 'Elie Hatem left Action Française to found a rival royalist group.'}, {'source': 'elie_hatem', 'target': 'konstantin_malofeev', 'label': 'Posed with', 'rationale': 'Elie Hatem posed with Konstantin Malofeev.'}, {'source': 'konstantin_malofeev', 'target': 'marine_le_pen', 'label': 'Provided loans to', 'rationale': 'Konstantin Malofeev provided Russian loans to Marine Le Pen.'}]
# start to process actor: {'id': 'elie_hatem', 'name': 'Elie Hatem', 'label': 'PERSON', 'key_information': 'Traveled to Moscow for the same event./nClose associate of Jean-Marie Le Pen./nDefended Bob Denard and Rifaat Al-Assad./nLeft Action Française to found a rival royalist group./nAdvised Boutros Boutros-Ghali./nHas connections in several countries./nHas a photo with Emmanuel Macron.'}
# RESOLVED, actor not created: {'id': 'elie_hatem', 'name': 'Elie Hatem', 'label': 'PERSON', 'key_information': 'Traveled to Moscow for the same event./nClose associate of Jean-Marie Le Pen./nDefended Bob Denard and Rifaat Al-Assad./nLeft Action Française to found a rival royalist group./nAdvised Boutros Boutros-Ghali./nHas connections in several countries./nHas a photo with Emmanuel Macron.'} resolved to (24, 'Elie I.', 'PERSON', "Elie I. is the driver of the Martel division, despite being only 16 years old and not having a driver's license.")
# start to process actor: {'id': 'jeanmarie_le_pen', 'name': 'Jean-Marie Le Pen', 'label': 'PERSON', 'key_information': 'Close associate of Elie Hatem.'}
# RESOLVED, actor not created: {'id': 'jeanmarie_le_pen', 'name': 'Jean-Marie Le Pen', 'label': 'PERSON', 'key_information': 'Close associate of Elie Hatem.'} resolved to (47, 'Marine Le Pen', 'PERSON', 'Marine Le Pen is a political figure associated with Châtillon and Loustau.')
# start to process actor: {'id': 'action_francaise', 'name': 'Action Française', 'label': 'ORGANIZATION', 'key_information': 'Elie Hatem left this group to found a rival royalist group.'}
# RESOLVED, actor not created: {'id': 'action_francaise', 'name': 'Action Française', 'label': 'ORGANIZATION', 'key_information': 'Elie Hatem left this group to found a rival royalist group.'} resolved to (67, 'Action Française', 'ORGANIZATION', 'Action Française is a political group with which Clément Girard is associated.')
# start to process actor: {'id': 'konstantin_malofeev', 'name': 'Konstantin Malofeev', 'label': 'PERSON', 'key_information': "Oligarch behind Marine Le Pen's Russian loans./nPosed with Elie Hatem."}
# start to process actor: {'id': 'marine_le_pen', 'name': 'Marine Le Pen', 'label': 'PERSON', 'key_information': 'Received Russian loans from Konstantin Malofeev.'}
# RESOLVED, actor not created: {'id': 'marine_le_pen', 'name': 'Marine Le Pen', 'label': 'PERSON', 'key_information': 'Received Russian loans from Konstantin Malofeev.'} resolved to (47, 'Marine Le Pen', 'PERSON', 'Marine Le Pen is a political figure associated with Châtillon and Loustau.')
# start to process rel: {'source': 'elie_hatem', 'target': 'jeanmarie_le_pen', 'label': 'Associate of', 'rationale': 'Elie Hatem is a close associate of Jean-Marie Le Pen.'}
# start to process rel: {'source': 'elie_hatem', 'target': 'action_francaise', 'label': 'Left', 'rationale': 'Elie Hatem left Action Française to found a rival royalist group.'}
# start to process rel: {'source': 'elie_hatem', 'target': 'konstantin_malofeev', 'label': 'Posed with', 'rationale': 'Elie Hatem posed with Konstantin Malofeev.'}
# start to process rel: {'source': 'konstantin_malofeev', 'target': 'marine_le_pen', 'label': 'Provided loans to', 'rationale': 'Konstantin Malofeev provided Russian loans to Marine Le Pen.'}
# Iteration ended at 2023-12-18 18:11:15.421216, duration: 0:00:07.090243

# %%
conn = sqlite3.connect("streetpress.db")
cursor = conn.cursor()    

query = "SELECT COUNT(*) FROM relationships"
cursor.execute(query)

# Fetch and print the results
print(cursor.fetchall())

# Close the connection
conn.close()
# Out:
# [(328,)]

# %%
display_table_sqlite("actors")
# Out:
# [(1, 'RNJ', 'ORGANIZATION', 'The RNJ is a radical youth organization that was relaunched in 2023./nThe RNJ organizes Forums for training and cohesion for its members and sympathizers./nThe RNJ has local sections, each with a responsible person.'), (2, 'Pierre-Romain Thionnet', 'PERSON', 'Pierre-Romain Thionnet is the head of the RNJ and the creator of the RNJ Forums./nHe has also held the position of national secretary at the Cocarde.'), (3, 'Aloys Vojinovic', 'PERSON', 'Aloys Vojinovic is a former member of the Zouaves Paris, a dissolved nazifying group, who attended a talk on the situation in Hungary at an RNJ Forum./nHe is known to some young RN leaders, including parliamentary attaché Luc Lahalle.'), (4, 'Eyquem Pons', 'PERSON', 'Eyquem Pons, also known as Etienne Cormier, is a cadre of Generation Identity who also attended a talk on the situation in Hungary at an RNJ Forum.'), (5, 'Luc Lahalle', 'PERSON', 'Luc Lahalle is a parliamentary attaché who often attends RNJ Forums and has been photographed with Aloys Vojinovic./nHe is the assistant of RN MEP Catherine Griset.'), (6, 'Catherine Griset', 'PERSON', 'Catherine Griset is an RN MEP whose assistant is Luc Lahalle.'), (7, 'Franck Allisio', 'PERSON', 'Franck Allisio is a local deputy who was invited to the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'), (8, 'Rafael F.', 'PERSON', 'Rafael F., also known as the militant pseudonym Raphaël Ayma, is the spokesperson for Tenesoun./nHe attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'), (9, 'Hélios C.', 'PERSON', "Hélios C. is a neofascist militant from Tenesoun who regularly hosts political 'spaces' on the social network Twitter-X./nHe attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône."), (10, 'Nicolas M.', 'PERSON', "Nicolas M. is a militant who has been through the UNI and has been photographed in front of a 'Clément deserves' tag and a Celtic cross with some members of Tenesoun.")]

# %%
print(get_rel_by_id(vct_rel_index.search("The Martel division has Mathis D. as a member.")[0]))
# Out:
# (21, 20, 22, 'has member', 'The Martel division has Mathis D. as a member.')

# %%
get_actor_by_id('20')
# Out:
# (20,
#  'Martel division',
#  'ORGANIZATION',
#  "The Martel division is a far-right group composed of about twenty minors or very young adults, mainly in Île-de-France./nThey have been involved in violent actions against children of Maghrebian origin or left-wing activists./nThey have been seen in various cities in France, including Rouen and Besançon./nThey have a Telegram group called 'Don't touch my WP', for White Power.")

# %%
new_rel = {'source': 'martel_division', 'target': 'mathis_d', 'label': 'has member', 'rationale': 'The Martel division has Mathis D. as a member.'}

# %%
actors_id_map = {
    'martel_division': '20',
    'mathis_d': '22'
}

# %%
process_rel(new_rel,vct_rel_index, actors_id_map)
# Out:
# 329

# %%
endpoints = [actors_id_map[new_rel['source']], actors_id_map[new_rel['target']]]
vct_search_raw_results = vct_rel_index.search(new_rel['rationale'])
filtered_vct_search_results = [result for result in vct_search_raw_results if (str(get_rel_by_id(result)[1]) in endpoints and str(get_rel_by_id(result)[2]) in endpoints)]
# if len(filtered_vct_search_results)==0:
#     rel_db_id = insert_relationship_sqlite(rel, actors_id_map)
#     vct_rel_index.insert_doc(rel['rationale'], rel_db_id)
#     return rel_db_id
# else:
#     print(f"RESOLVED, rel not created: {rel} resolved to {get_rel_by_id(filtered_vct_search_results[0])}, relationship not created.")

# %%
endpoints
# Out:
# ['20', '22']

# %%
filtered_vct_search_results
# Out:
# ['21', '329', '46', '313']

# %%
vct_search_raw_results
# Out:
# ['21', '329', '46', '313']

# %%
for result in vct_search_raw_results:
    print(f"Full result: {result}")
    source_id = get_rel_by_id(result)[1]
    print(f"Source ID: {source_id}")
    target_id = get_rel_by_id(result)[2]
    print(f"Target ID: {target_id}")
    print(f"Condition 1: {str(source_id) in endpoints}")
    print(f"Condition 2: {str(target_id) in endpoints}")
    print(f"Combined conditions: {(str(source_id) in endpoints and str(target_id) in endpoints)}")
# Out:
# Full result: 21
# Source ID: 20
# Target ID: 22
# Condition 1: True
# Condition 2: True
# Combined conditions: True
# Full result: 329
# Source ID: 20
# Target ID: 22
# Condition 1: True
# Condition 2: True
# Combined conditions: True
# Full result: 46
# Source ID: 20
# Target ID: 22
# Condition 1: True
# Condition 2: True
# Combined conditions: True
# Full result: 313
# Source ID: 20
# Target ID: 22
# Condition 1: True
# Condition 2: True
# Combined conditions: True

# %%
print('20' in endpoints)
# Out:
# True
