# %% [markdown]
# # Goal & Approach
#
# The goal of this file is to build a unified Knowledge Graph of actors and relationships based on the entities detected in the streetpress_extract_entities.ipynb file.
#
# In that previous extraction steps, entities were extracted from multiple chunks of texts coming from multiple articles. Those entities and relationships were stored in separate files.
#
# The challenge here is to aggregate and resolve all these entities and relationships to build one big graph with as few duplicates as possible.
#
# The resolution relies on 2 components : a full-text search index and a vector search index. And the final source of truth for resolved entities is a Sqlite instance.
#
# <img src="streetpress_resolution.png" width="800" height="480">

# %% [markdown]
# # How to run this file
#
# Required:
# - An OpenAI API key
#
# Your secrets (API keys) must be put in a ".env" file in the same folder as this file.
# The format should be OPENAI_API_KEY = "sk-..." (replace with your own key)

# %%
import os
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %% [markdown]
# # Retrieve LLM reponses' data

# %%
# Load entities from disk

import json
import os
import glob

def load_entities_from_file(file_path):
    # Load data from the file
    actors = []
    rels = []
    with open(file_path, 'r') as file:
        data = json.load(file)
        actors = data['actors']
        rels = data['relationships']

    return actors, rels


def get_llm_files_paths(folder_name="llm_responses"):
    folder_path = os.path.join(".", folder_name)

    # Check if the folder exists
    if not os.path.exists(folder_path):
        print(f"Folder not found: {folder_path}")
        return None

    # Pattern to match files of the form 'article-x_chunk-y.json'
    pattern = os.path.join(folder_path, "article-*_chunk-*.json")

    # Find all matching files
    file_paths = glob.glob(pattern)

    return file_paths

# %%
# Test on the first chunk of the first article

file_path = "./llm_responses/article-1_chunk-1.json"
actors, rels = load_entities_from_file(file_path)
print(actors)
print(rels)
# Out:
# [{'id': 'kata_fight_club', 'name': 'Kata fight club', 'label': 'ORGANIZATION', 'key_information': 'It is the name of the underground fight club.'}, {'id': 'gud', 'name': 'Gud', 'label': 'ORGANIZATION', 'key_information': 'It is a right-wing extremist group.'}, {'id': 'generation_identitaire', 'name': 'Génération identitaire', 'label': 'ORGANIZATION', 'key_information': 'It is a right-wing extremist group.'}, {'id': 'zouaves', 'name': 'Zouaves', 'label': 'ORGANIZATION', 'key_information': 'It is a neo-Nazi group.'}, {'id': 'remi_g', 'name': 'Rémi G.', 'label': 'PERSON', 'key_information': 'He is a main participant of the right-wing extremist fight club./nHe attended a prestigious military school./nHe shares his drawings and other content on Instagram and YouTube./nHe is part of the Catholic identitarian movement Academia Christiana.'}, {'id': 'herve_ryssen', 'name': 'Hervé Ryssen', 'label': 'PERSON', 'key_information': 'He is an antisemitic and conspiracist French person whose documentaries Rémi G. shares.'}, {'id': 'marc_de_cacqueray', 'name': 'Marc de Cacqueray', 'label': 'PERSON', 'key_information': 'He is the leader of Gud and a known right-wing extremist.'}, {'id': 'loutres_gang', 'name': 'Loutres Gang', 'label': 'ORGANIZATION', 'key_information': 'It is a group of fighters from the right-wing extremist groups Auctorum and Luminis.'}, {'id': 'auctorum', 'name': 'Auctorum', 'label': 'ORGANIZATION', 'key_information': 'It is a right-wing extremist group.'}, {'id': 'luminis', 'name': 'Luminis', 'label': 'ORGANIZATION', 'key_information': 'It is a right-wing extremist group.'}, {'id': 'academia_christiana', 'name': 'Academia Christiana', 'label': 'ORGANIZATION', 'key_information': 'It is a Catholic identitarian movement that Rémi G. is part of.'}]
# [{'source': 'remi_g', 'target': 'gud', 'label': 'member of', 'rationale': 'Rémi G. is a member of Gud.'}, {'source': 'remi_g', 'target': 'academia_christiana', 'label': 'member of', 'rationale': 'Rémi G. is a member of Academia Christiana.'}, {'source': 'herve_ryssen', 'target': 'remi_g', 'label': 'content shared by', 'rationale': "Hervé Ryssen's documentaries are shared by Rémi G."}, {'source': 'marc_de_cacqueray', 'target': 'gud', 'label': 'leader of', 'rationale': 'Marc de Cacqueray is the leader of Gud.'}, {'source': 'loutres_gang', 'target': 'auctorum', 'label': 'composed of', 'rationale': 'Loutres Gang is composed of members from Auctorum.'}, {'source': 'loutres_gang', 'target': 'luminis', 'label': 'composed of', 'rationale': 'Loutres Gang is composed of members from Luminis.'}]

# %% [markdown]
# # Create the SQLite DB

# %%
# Boilerplate to interact with SQLite

import sqlite3
import os


def create_sqlite_db(db_name='streetpress.db'):
    # Check if the database file exists
    if os.path.exists(db_name):
        # Delete the file
        os.remove(db_name)
    
    # Creates a new db with that name
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Create table with an auto-incrementing primary key
    cursor.execute('''
        CREATE TABLE IF NOT EXISTS actors (
            id INTEGER PRIMARY KEY,
            name TEXT NOT NULL,
            label TEXT NOT NULL,
            key_information TEXT
        )
    ''')

    cursor.execute('''
        CREATE TABLE IF NOT EXISTS relationships (
            id INTEGER PRIMARY KEY,
            source_actor INTEGER,
            target_actor INTEGER,
            label TEXT NOT NULL,
            rationale TEXT,
            FOREIGN KEY (source_actor) REFERENCES actors (id),
            FOREIGN KEY (target_actor) REFERENCES actors (id)
        )
    ''')

    # Commit and close
    conn.commit()
    conn.close()


def insert_actor_sqlite(actor, db_name="streetpress.db"):
    # Connect to the db
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Insert a new row without specifying the ID
    cursor.execute('''
        INSERT INTO actors (name, label, key_information) VALUES (?, ?, ?)
    ''', (actor['name'], actor['label'], actor['key_information']))

    # Retrieve the ID of the newly inserted row
    inserted_row_id = cursor.lastrowid

    # Commit and close
    conn.commit()
    conn.close()

    return inserted_row_id

def insert_relationship_sqlite(rel, actors_id_map, db_name="streetpress.db"):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    # Insert a new row without specifying the ID
    cursor.execute('''
        INSERT INTO relationships (source_actor, target_actor, label, rationale) VALUES (?, ?, ?, ?)
    ''', (actors_id_map[rel['source']], actors_id_map[rel['target']], rel['label'], rel['rationale']))

    # Retrieve the ID of the newly inserted row
    inserted_row_id = cursor.lastrowid

    # Commit and close
    conn.commit()
    conn.close()

    return inserted_row_id

def display_table_sqlite(table_name, db_name="streetpress.db"):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()    

    query = "SELECT * FROM " + table_name + " LIMIT 10"
    cursor.execute(query)

    # Fetch and print the results
    print(cursor.fetchall())

    # Close the connection
    conn.close()

def get_actor_by_id(actor_id, db_name="streetpress.db"):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    query = "SELECT * FROM actors WHERE id = ?"
    cursor.execute(query, (actor_id,))

    # Fetch and return the result
    result = cursor.fetchone()

    # Close the connection
    conn.close()

    return result

def get_rel_by_id(rel_id, db_name="streetpress.db"):
    conn = sqlite3.connect(db_name)
    cursor = conn.cursor()

    query = "SELECT * FROM relationships WHERE id = ?"
    cursor.execute(query, (rel_id,))

    # Fetch and return the result
    result = cursor.fetchone()

    # Close the connection
    conn.close()

    return result

# %%
# Run an example

create_sqlite_db()
actors_id_map = {}
for actor in actors:
    actor_db_id = insert_actor_sqlite(actor)
    actors_id_map[actor['id']] = actor_db_id
for rel in rels:
    insert_relationship_sqlite(rel,actors_id_map)
display_table_sqlite("actors")
# Out:
# [(1, 'Kata fight club', 'ORGANIZATION', 'It is the name of the underground fight club.'), (2, 'Gud', 'ORGANIZATION', 'It is a right-wing extremist group.'), (3, 'Génération identitaire', 'ORGANIZATION', 'It is a right-wing extremist group.'), (4, 'Zouaves', 'ORGANIZATION', 'It is a neo-Nazi group.'), (5, 'Rémi G.', 'PERSON', 'He is a main participant of the right-wing extremist fight club./nHe attended a prestigious military school./nHe shares his drawings and other content on Instagram and YouTube./nHe is part of the Catholic identitarian movement Academia Christiana.'), (6, 'Hervé Ryssen', 'PERSON', 'He is an antisemitic and conspiracist French person whose documentaries Rémi G. shares.'), (7, 'Marc de Cacqueray', 'PERSON', 'He is the leader of Gud and a known right-wing extremist.'), (8, 'Loutres Gang', 'ORGANIZATION', 'It is a group of fighters from the right-wing extremist groups Auctorum and Luminis.'), (9, 'Auctorum', 'ORGANIZATION', 'It is a right-wing extremist group.'), (10, 'Luminis', 'ORGANIZATION', 'It is a right-wing extremist group.')]

# %% [markdown]
# # Create a full-text index with Whoosh

# %% [markdown]
# Observations:
# - The main QueryParser on the "name" works with OR allowing for partial match on groups of words
# - Fuzziness is applied for words that are 4 letters or more
# - Any match (whatever its score) is accepted

# %%
from whoosh.fields import Schema, TEXT, ID
from whoosh.analysis import StandardAnalyzer
from whoosh.index import create_in
from whoosh.qparser import QueryParser, FuzzyTermPlugin, OrGroup
import os.path
import shutil

class FullTextIndex:
    def __init__(self, ft_index_name="streetpress_ft_index"):
        self.schema = Schema(name=TEXT(stored=True, analyzer=StandardAnalyzer()), sqlite_id=ID(stored=True))

        if os.path.exists(ft_index_name):
            shutil.rmtree(ft_index_name)
        os.mkdir(ft_index_name)

        self.index = create_in(ft_index_name, self.schema)
        self.setup_query_parsers()

    def setup_query_parsers(self):
        self.name_qp = QueryParser("name", schema=self.index.schema, group=OrGroup.factory(0.9))
        self.name_qp.add_plugin(FuzzyTermPlugin())
        self.sqlite_id_qp = QueryParser("sqlite_id", schema=self.index.schema)

    def insert_doc(self, entity_name, sqlite_id):
        with self.index.writer() as writer:
            writer.add_document(name=entity_name, sqlite_id=str(sqlite_id))

    def name_search(self, text, FT_THREASHOLD=5):
        query_words = text.split()
        combined_query = " OR ".join([f"{word}~" if len(word) > 3 else word for word in query_words])
        q = self.name_qp.parse(combined_query)
        extracted_results = []

        with self.index.searcher() as s:
            results = s.search(q)
            if len(results) > 0:
                extracted_results = [{"name": result['name'], "sqlite_id": result['sqlite_id'], "score": result.score} for result in results if result.score>FT_THREASHOLD]

        return extracted_results

# %%
# Run an example 

create_sqlite_db()
ft_index = FullTextIndex()
actors_id_map = {}
for actor in actors:
    actor_db_id = insert_actor_sqlite(actor)
    ft_index.insert_doc(actor['name'], actor_db_id)
    actors_id_map[actor['id']] = actor_db_id

# %%
with ft_index.index.searcher() as searcher:
    for doc in searcher.documents():
        print(doc)
# Out:
# {'name': 'Academia Christiana', 'sqlite_id': '11'}
# {'name': 'Marc de Cacqueray', 'sqlite_id': '7'}
# {'name': 'Loutres Gang', 'sqlite_id': '8'}
# {'name': 'Auctorum', 'sqlite_id': '9'}
# {'name': 'Luminis', 'sqlite_id': '10'}
# {'name': 'Hervé Ryssen', 'sqlite_id': '6'}
# {'name': 'Kata fight club', 'sqlite_id': '1'}
# {'name': 'Gud', 'sqlite_id': '2'}
# {'name': 'Génération identitaire', 'sqlite_id': '3'}
# {'name': 'Zouaves', 'sqlite_id': '4'}
# {'name': 'Rémi G.', 'sqlite_id': '5'}

# %%
ft_index.name_search("La Dissidence Française")
# Out:
# []

# %% [markdown]
# # Create a vector index with faiss

# %% [markdown]
# Observations:
# - The distance measure used is the Euclidian distance (default with faiss)
# - The maximum distance used is 0.2

# %%
# Initialize the vector store
import faiss
import numpy as np
from langchain.vectorstores import FAISS
from langchain.docstore.in_memory import InMemoryDocstore
from langchain.vectorstores.utils import DistanceStrategy
from langchain.embeddings.openai import OpenAIEmbeddings

class VectorIndex:
    def __init__(self):
        self.embedding_engine = OpenAIEmbeddings()
        sample_embedding = self.embedding_engine.embed_documents(["Sample text"])[0]

        self.vct_index = faiss.IndexFlatL2(len(sample_embedding))
        self.vct_db = FAISS(
            self.embedding_engine,
            self.vct_index,
            InMemoryDocstore(),
            {},
            normalize_L2=False,
            distance_strategy=DistanceStrategy.EUCLIDEAN_DISTANCE
        )

    def insert_doc(self, text, sqlite_id):
        self.vct_db.add_texts([text], [{"sqlite_id": str(sqlite_id)}])

    def search(self, text, MAX_DIST=0.2):
        results = self.vct_db.similarity_search_with_score(text)
        filtered_results = [result[0].metadata['sqlite_id'] for result in results if result[1]< MAX_DIST]

        return filtered_results

# %%
# Run an example

create_sqlite_db()
ft_index = FullTextIndex()
vct_actor_index = VectorIndex()
vct_rel_index = VectorIndex()

actors_id_map = {}
for actor in actors:
    actor_sqlite_id = insert_actor_sqlite(actor)
    ft_index.insert_doc(actor['name'], actor_sqlite_id)
    vct_actor_index.insert_doc(actor['key_information'], actor_sqlite_id)
    actors_id_map[actor['id']] = actor_sqlite_id

for rel in rels:
    rel_sqlite_id = insert_relationship_sqlite(rel, actors_id_map)
    vct_rel_index.insert_doc(rel['rationale'], rel_sqlite_id)

# %%
print(get_actor_by_id(vct_actor_index.search("It is the name of the underground fight club.")[0]))
print(get_actor_by_id(vct_actor_index.search("He is a main participant of the right-wing extremist fight club.")[0]))
# Out:
# (1, 'Kata fight club', 'ORGANIZATION', 'It is the name of the underground fight club.')
# (5, 'Rémi G.', 'PERSON', 'He is a main participant of the right-wing extremist fight club./nHe attended a prestigious military school./nHe shares his drawings and other content on Instagram and YouTube./nHe is part of the Catholic identitarian movement Academia Christiana.')

# %%
print(get_rel_by_id(vct_rel_index.search("Rémi G. is a member of Gud.")[0]))
# Out:
# (1, 5, 2, 'member of', 'Rémi G. is a member of Gud.')

# %% [markdown]
# # Entity resolution

# %% [markdown]
# Observations:
# - Vector search was initially applied on actors' key information if the full-text search came back empty. But it was removed (commented section): the information provided by the LLM was sometimes too succinct, generating false positives.
# - The vector search seams to be letting through quite a few duplicates for the relationships as well. Some tuning or alternative strategies would be needed.

# %%
import logging
import datetime
import os

def ensure_log_directory_exists(directory):
    if not os.path.exists(directory):
        os.makedirs(directory)

def setup_logger(directory):
    current_time = datetime.datetime.now()
    log_filename = f"process_log_{current_time.strftime('%Y%m%d_%H%M%S')}.txt"
    log_filepath = os.path.join(directory, log_filename)

    logger = logging.getLogger('MyLogger')
    logger.setLevel(logging.INFO)

    file_handler = logging.FileHandler(log_filepath)
    formatter = logging.Formatter('%(asctime)s - %(message)s')
    file_handler.setFormatter(formatter)

    logger.addHandler(file_handler)
    return logger

# %%
def process_actor(actor, ft__actor_index, vct_actor_index, actors_id_map):
    ft_actor_search_results = ft__actor_index.name_search(actor['name'])
    vct_actor_search_results = vct_actor_index.search(actor['key_information'])

    if len(ft_actor_search_results)>0:
        resolved_id = ft_actor_search_results[0]['sqlite_id']
        ft_index.insert_doc(actor['name'], resolved_id)
        vct_actor_index.insert_doc(actor['key_information'], resolved_id)
        actors_id_map[actor['id']] = resolved_id
        message = f"RESOLVED ACTOR: {actor['name']} => {get_actor_by_id(resolved_id)[1]}"
        logger.info(message)
        print(message)
    # elif len(vct_actor_search_results)>0:
    #     resolved_id = vct_actor_search_results[0]
    #     ft_index.insert_doc(actor['name'], resolved_id)
    #     vct_actor_index.insert_doc(actor['key_information'], resolved_id)
    #     actors_id_map[actor['id']] = resolved_id
    else:
        actor_db_id = insert_actor_sqlite(actor)
        ft_index.insert_doc(actor['name'], actor_db_id)
        vct_actor_index.insert_doc(actor['key_information'], actor_db_id)
        actors_id_map[actor['id']] = actor_db_id
        message = f"CREATED ACTOR: {actor['name']} with DB ID {actor_db_id}"
        logger.info(message)
        print(message)
    
    return actors_id_map

def process_rel(rel, vct_rel_index, actors_id_map):
    endpoints = [actors_id_map[rel['source']], actors_id_map[rel['target']]]
    vct_search_raw_results = vct_rel_index.search(rel['rationale'])
    filtered_vct_search_results = [result for result in vct_search_raw_results if (str(get_rel_by_id(result)[1]) in endpoints and str(get_rel_by_id(result)[2]) in endpoints)]
    if len(filtered_vct_search_results)==0:
        rel_db_id = insert_relationship_sqlite(rel, actors_id_map)
        vct_rel_index.insert_doc(rel['rationale'], rel_db_id)
        message = f"CREATED REL: {rel}"
        logger.info(message)
        print(message)
        return rel_db_id
    else:
        message = f"RESOLVED REL: {rel} resolved to {get_rel_by_id(filtered_vct_search_results[0])}"
        logger.info(message)
        print(message)

# %%
# Run an example

create_sqlite_db()
ft_actor_index = FullTextIndex()
vct_actor_index = VectorIndex()
vct_rel_index = VectorIndex()
log_directory = "log_files"
ensure_log_directory_exists(log_directory)
logger = setup_logger(log_directory)

actors_id_map = {}
for actor in actors:
    process_actor(actor, ft_actor_index, vct_actor_index, actors_id_map)

# %%
for rel in rels:
    process_rel(rel, vct_rel_index,actors_id_map)

# %% [markdown]
# # Process all the files

# %%
# Prepare the DB and the indexes

create_sqlite_db()
ft_actor_index = FullTextIndex()
vct_actor_index = VectorIndex()
vct_rel_index = VectorIndex()
log_directory = "log_files"
ensure_log_directory_exists(log_directory)
logger = setup_logger(log_directory)

# %%
import datetime

# Find all matching files
file_paths = get_llm_files_paths()
print(file_paths)

for file_path in file_paths:
    message = f"FILE: starting to process {file_path}"
    logger.info(message)
    print(message)
    start_time = datetime.datetime.now()
    print(f"Iteration started at {start_time}")
    file_actors, file_rels = load_entities_from_file(file_path)
    actors_id_map = {}
    
    for actor in file_actors:
        #print(f"start to process actor: {actor}")
        process_actor(actor, ft_actor_index, vct_actor_index, actors_id_map)

    for rel in file_rels:
        #print(f"start to process rel: {rel}")
        process_rel(rel, vct_rel_index, actors_id_map)

    end_time = datetime.datetime.now()
    duration = end_time - start_time
    print(f"Iteration ended at {end_time}, duration: {duration}")
# Out:
# ['./llm_responses/article-7_chunk-2.json', './llm_responses/article-19_chunk-1.json', './llm_responses/article-2_chunk-1.json', './llm_responses/article-5_chunk-1.json', './llm_responses/article-28_chunk-1.json', './llm_responses/article-39_chunk-2.json', './llm_responses/article-18_chunk-1.json', './llm_responses/article-4_chunk-1.json', './llm_responses/article-29_chunk-1.json', './llm_responses/article-3_chunk-1.json', './llm_responses/article-7_chunk-3.json', './llm_responses/article-23_chunk-1.json', './llm_responses/article-10_chunk-2.json', './llm_responses/article-42_chunk-2.json', './llm_responses/article-17_chunk-2.json', './llm_responses/article-36_chunk-1.json', './llm_responses/article-31_chunk-1.json', './llm_responses/article-34_chunk-2.json', './llm_responses/article-15_chunk-1.json', './llm_responses/article-40_chunk-1.json', './llm_responses/article-12_chunk-1.json', './llm_responses/article-16_chunk-2.json', './llm_responses/article-11_chunk-2.json', './llm_responses/article-30_chunk-1.json', './llm_responses/article-37_chunk-1.json', './llm_responses/article-22_chunk-1.json', './llm_responses/article-25_chunk-1.json', './llm_responses/article-8_chunk-1.json', './llm_responses/article-35_chunk-2.json', './llm_responses/article-32_chunk-2.json', './llm_responses/article-41_chunk-1.json', './llm_responses/article-14_chunk-1.json', './llm_responses/article-27_chunk-2.json', './llm_responses/article-20_chunk-2.json', './llm_responses/article-35_chunk-1.json', './llm_responses/article-13_chunk-2.json', './llm_responses/article-24_chunk-3.json', './llm_responses/article-20_chunk-1.json', './llm_responses/article-16_chunk-1.json', './llm_responses/article-43_chunk-1.json', './llm_responses/article-11_chunk-1.json', './llm_responses/article-21_chunk-1.json', './llm_responses/article-26_chunk-1.json', './llm_responses/article-33_chunk-1.json', './llm_responses/article-34_chunk-1.json', './llm_responses/article-24_chunk-2.json', './llm_responses/article-10_chunk-1.json', './llm_responses/article-42_chunk-1.json', './llm_responses/article-17_chunk-1.json', './llm_responses/article-13_chunk-3.json', './llm_responses/article-29_chunk-2.json', './llm_responses/article-3_chunk-2.json', './llm_responses/article-39_chunk-1.json', './llm_responses/article-1_chunk-1.json', './llm_responses/article-2_chunk-3.json', './llm_responses/article-6_chunk-1.json', './llm_responses/article-2_chunk-2.json', './llm_responses/article-5_chunk-2.json', './llm_responses/article-29_chunk-3.json', './llm_responses/article-38_chunk-1.json']
# FILE: starting to process ./llm_responses/article-7_chunk-2.json
# Iteration started at 2023-12-19 14:54:02.448989
# CREATED ACTOR: RNJ with DB ID 1
# CREATED ACTOR: Pierre-Romain Thionnet with DB ID 2
# CREATED ACTOR: Forums RNJ with DB ID 3
# CREATED ACTOR: Aloys Vojinovic with DB ID 4
# CREATED ACTOR: Eyquem Pons with DB ID 5
# CREATED ACTOR: Luc Lahalle with DB ID 6
# CREATED ACTOR: Catherine Griset with DB ID 7
# CREATED ACTOR: Franck Allisio with DB ID 8
# CREATED ACTOR: Rafael F. with DB ID 9
# CREATED ACTOR: Hélios C. with DB ID 10
# CREATED ACTOR: Nicolas M. with DB ID 11
# CREATED ACTOR: Édouard Bina with DB ID 12
# CREATED ACTOR: Sinisha Milinov with DB ID 13
# CREATED ACTOR: Julien Chmielewski with DB ID 14
# CREATED ACTOR: Clément Girard with DB ID 15
# CREATED ACTOR: Frank Giletti with DB ID 16
# CREATED ACTOR: Frédéric Boccaletti with DB ID 17
# CREATED REL: {'source': 'rnj', 'target': 'pierreromain_thionnet', 'label': 'Leader', 'rationale': 'Pierre-Romain Thionnet is the leader of the RNJ.'}
# CREATED REL: {'source': 'rnj', 'target': 'forums_rnj', 'label': 'Organizer', 'rationale': 'The RNJ organizes the RNJ Forums.'}
# CREATED REL: {'source': 'pierreromain_thionnet', 'target': 'forums_rnj', 'label': 'Creator', 'rationale': 'Pierre-Romain Thionnet created the RNJ Forums.'}
# CREATED REL: {'source': 'rnj', 'target': 'aloys_vojinovic', 'label': 'Attendee', 'rationale': 'Aloys Vojinovic attended an RNJ Forum.'}
# CREATED REL: {'source': 'rnj', 'target': 'eyquem_pons', 'label': 'Attendee', 'rationale': 'Eyquem Pons attended an RNJ Forum.'}
# CREATED REL: {'source': 'rnj', 'target': 'luc_lahalle', 'label': 'Attendee', 'rationale': 'Luc Lahalle often attends RNJ Forums.'}
# CREATED REL: {'source': 'luc_lahalle', 'target': 'catherine_griset', 'label': 'Assistant', 'rationale': 'Luc Lahalle is the assistant of Catherine Griset.'}
# CREATED REL: {'source': 'rnj', 'target': 'franck_allisio', 'label': 'Host', 'rationale': 'The RNJ of Bouches-du-Rhône hosted Franck Allisio for the first Southern Forum.'}
# CREATED REL: {'source': 'rnj', 'target': 'rafael_f', 'label': 'Attendee', 'rationale': 'Rafael F. attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'}
# CREATED REL: {'source': 'rnj', 'target': 'helios_c', 'label': 'Attendee', 'rationale': 'Hélios C. attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'}
# CREATED REL: {'source': 'rnj', 'target': 'nicolas_m', 'label': 'Leader', 'rationale': 'Édouard Bina is the head of RNJ 74.'}
# CREATED REL: {'source': 'nicolas_m', 'target': 'edouard_bina', 'label': 'Colleague', 'rationale': 'Édouard Bina and Sinisha Milinov met at the Cocarde Lyon.'}
# CREATED REL: {'source': 'rnj', 'target': 'sinisha_milinov', 'label': 'Leader', 'rationale': 'Julien Chmielewski is the head of RNJ Puy-de-Dôme.'}
# CREATED REL: {'source': 'julien_chmielewski', 'target': 'clement_girard', 'label': 'Colleague', 'rationale': 'Clément Girard is seen alongside deputies Frank Giletti and Frédéric Boccaletti.'}
# CREATED REL: {'source': 'julien_chmielewski', 'target': 'frank_giletti', 'label': 'Colleague', 'rationale': 'Clément Girard is seen alongside deputies Frank Giletti and Frédéric Boccaletti.'}
# Iteration ended at 2023-12-19 14:54:20.221815, duration: 0:00:17.772826
# FILE: starting to process ./llm_responses/article-19_chunk-1.json
# Iteration started at 2023-12-19 14:54:20.222163
# CREATED ACTOR: Pierre T. with DB ID 18
# CREATED ACTOR: Gud with DB ID 19
# CREATED ACTOR: Franck Cuter with DB ID 20
# CREATED ACTOR: François Delagrande with DB ID 21
# CREATED ACTOR: Bastion social with DB ID 22
# CREATED ACTOR: Edelweiss with DB ID 23
# CREATED ACTOR: Bastien C. with DB ID 24
# CREATED REL: {'source': 'franck_cuter', 'target': 'bastion_social', 'label': 'participated in', 'rationale': 'Franck Cuter participated in the neo-fascist group Bastion social.'}
# CREATED REL: {'source': 'francois_delagrande', 'target': 'bastion_social', 'label': 'participated in', 'rationale': 'François Delagrande participated in the neo-fascist group Bastion social.'}
# Iteration ended at 2023-12-19 14:54:25.706048, duration: 0:00:05.483885
# FILE: starting to process ./llm_responses/article-2_chunk-1.json
# Iteration started at 2023-12-19 14:54:25.706416
# CREATED ACTOR: Pierre C. with DB ID 25
# CREATED ACTOR: Martel division with DB ID 26
# CREATED ACTOR: Antoine C. with DB ID 27
# CREATED ACTOR: Mathis D. with DB ID 28
# CREATED ACTOR: Léo R. with DB ID 29
# CREATED ACTOR: Elie I. with DB ID 30
# CREATED ACTOR: Vandal Besak with DB ID 31
# CREATED ACTOR: Korrigans Squad with DB ID 32
# CREATED ACTOR: Marc de Cacqueray-Valmenier with DB ID 33
# CREATED REL: {'source': 'pierre_c', 'target': 'martel_division', 'label': 'member of', 'rationale': 'Pierre C. is a member of the Martel division.'}
# CREATED REL: {'source': 'martel_division', 'target': 'pierre_c', 'label': 'has member', 'rationale': 'The Martel division has Pierre C. as a member.'}
# CREATED REL: {'source': 'martel_division', 'target': 'antoine_c', 'label': 'has member', 'rationale': 'The Martel division has Antoine C. as a member.'}
# CREATED REL: {'source': 'martel_division', 'target': 'mathis_d', 'label': 'has member', 'rationale': 'The Martel division has Mathis D. as a member.'}
# CREATED REL: {'source': 'martel_division', 'target': 'leo_r', 'label': 'has member', 'rationale': 'The Martel division has Léo R. as a member.'}
# CREATED REL: {'source': 'martel_division', 'target': 'elie_i', 'label': 'has member', 'rationale': 'The Martel division has Elie I. as a member.'}
# CREATED REL: {'source': 'martel_division', 'target': 'vandal_besak', 'label': 'associated with', 'rationale': 'The Martel division has been seen with the Vandal Besak in Besançon.'}
# CREATED REL: {'source': 'martel_division', 'target': 'korrigans_squad', 'label': 'associated with', 'rationale': 'The Martel division has been seen with the Korrigans Squad in Besançon.'}
# CREATED REL: {'source': 'martel_division', 'target': 'marc_de_cacquerayvalmenier', 'label': 'caused embarrassment to', 'rationale': 'The erratic behavior of the Martel division caused embarrassment to Marc de Cacqueray-Valmenier.'}
# Iteration ended at 2023-12-19 14:54:35.092186, duration: 0:00:09.385770
# FILE: starting to process ./llm_responses/article-5_chunk-1.json
# Iteration started at 2023-12-19 14:54:35.092606
# CREATED ACTOR: Jean-Eudes Gannat with DB ID 34
# CREATED ACTOR: Alvarium with DB ID 35
# CREATED ACTOR: Mouvement Chouan with DB ID 36
# CREATED ACTOR: Raphaël Ayma with DB ID 37
# CREATED ACTOR: Tenesoun with DB ID 38
# CREATED ACTOR: Argos with DB ID 39
# CREATED ACTOR: French lives matter with DB ID 40
# CREATED ACTOR: Rassemblement national with DB ID 41
# CREATED ACTOR: Edouard Bina with DB ID 42
# RESOLVED ACTOR: Rassemblement national de la jeunesse => Rassemblement national
# CREATED ACTOR: Cocarde with DB ID 43
# CREATED ACTOR: Nina Azamberti with DB ID 44
# CREATED ACTOR: Némésis with DB ID 45
# CREATED ACTOR: Defends Marseille with DB ID 46
# CREATED ACTOR: Stéphane Ravier with DB ID 47
# RESOLVED ACTOR: Gud => Gud
# CREATED ACTOR: Natifs with DB ID 48
# CREATED ACTOR: Nationalistes révolutionnaires with DB ID 49
# CREATED ACTOR: Génération identitaire with DB ID 50
# CREATED ACTOR: Christian Bouchet with DB ID 51
# CREATED REL: {'source': 'jeaneudes_gannat', 'target': 'alvarium', 'label': 'Former leader', 'rationale': 'Jean-Eudes Gannat was the former leader of the Alvarium group.'}
# CREATED REL: {'source': 'jeaneudes_gannat', 'target': 'mouvement_chouan', 'label': 'Current leader', 'rationale': 'Jean-Eudes Gannat is the current leader of the Mouvement Chouan.'}
# CREATED REL: {'source': 'raphael_ayma', 'target': 'tenesoun', 'label': 'Member', 'rationale': 'Raphaël Ayma is a member of the Tenesoun group.'}
# CREATED REL: {'source': 'edouard_bina', 'target': 'nemesis', 'label': 'Boss', 'rationale': 'Edouard Bina is the boss of the Rassemblement national de la jeunesse.'}
# CREATED REL: {'source': 'nina_azamberti', 'target': 'gud', 'label': 'Campaigner', 'rationale': 'Nina Azamberti campaigns for Némésis.'}
# CREATED REL: {'source': 'nina_azamberti', 'target': 'natifs', 'label': 'Campaigner', 'rationale': 'Nina Azamberti campaigns for Defends Marseille.'}
# CREATED REL: {'source': 'christian_bouchet', 'target': 'nationalistes_revolutionnaires', 'label': 'Leading figure', 'rationale': 'Christian Bouchet is a leading figure in the nationalistes révolutionnaires.'}
# Iteration ended at 2023-12-19 14:54:51.776623, duration: 0:00:16.684017
# FILE: starting to process ./llm_responses/article-28_chunk-1.json
# Iteration started at 2023-12-19 14:54:51.776799
# CREATED ACTOR: Dominique Delawarde with DB ID 52
# Iteration ended at 2023-12-19 14:54:52.228335, duration: 0:00:00.451536
# FILE: starting to process ./llm_responses/article-39_chunk-2.json
# Iteration started at 2023-12-19 14:54:52.228749
# CREATED ACTOR: Gud with DB ID 53
# CREATED ACTOR: Marc de Cacqueray-Valménier with DB ID 54
# CREATED ACTOR: Châtillon with DB ID 55
# CREATED ACTOR: Loustau with DB ID 56
# CREATED ACTOR: Marine Le Pen with DB ID 57
# CREATED REL: {'source': 'gud', 'target': 'marc_de_cacquerayvalmenier', 'label': 'includes', 'rationale': 'The Gud includes Marc de Cacqueray-Valménier.'}
# CREATED REL: {'source': 'gud', 'target': 'chatillon', 'label': 'was led by', 'rationale': 'The Gud was led by Châtillon.'}
# CREATED REL: {'source': 'gud', 'target': 'loustau', 'label': 'was led by', 'rationale': 'The Gud was led by Loustau.'}
# CREATED REL: {'source': 'chatillon', 'target': 'marine_le_pen', 'label': 'is associated with', 'rationale': 'Châtillon is associated with Marine Le Pen.'}
# CREATED REL: {'source': 'loustau', 'target': 'marine_le_pen', 'label': 'is associated with', 'rationale': 'Loustau is associated with Marine Le Pen.'}
# Iteration ended at 2023-12-19 14:54:57.015994, duration: 0:00:04.787245
# FILE: starting to process ./llm_responses/article-18_chunk-1.json
# Iteration started at 2023-12-19 14:54:57.016566
# CREATED ACTOR: Les Burners with DB ID 58
# CREATED ACTOR: Gremium MC with DB ID 59
# CREATED ACTOR: Serge Ayoub with DB ID 60
# CREATED ACTOR: Troisième Voie with DB ID 61
# RESOLVED ACTOR: Jeunesses nationalistes révolutionnaires (JNR) => Nationalistes révolutionnaires
# CREATED ACTOR: Gabriel Decouture with DB ID 62
# CREATED ACTOR: Black Shadow North with DB ID 63
# CREATED REL: {'source': 'les_burners', 'target': 'gremium_mc', 'label': 'Supports', 'rationale': "Les Burners is a 'club support Black Seven' for Gremium MC."}
# CREATED REL: {'source': 'gremium_mc', 'target': 'serge_ayoub', 'label': 'Led by', 'rationale': 'Gremium MC is led by Serge Ayoub.'}
# CREATED REL: {'source': 'serge_ayoub', 'target': 'troisieme_voie', 'label': 'Former leader of', 'rationale': 'Serge Ayoub is the former leader of Troisième Voie.'}
# CREATED REL: {'source': 'serge_ayoub', 'target': 'jeunesses_nationalistes_revolutionnaires_jnr', 'label': 'Former leader of', 'rationale': 'Serge Ayoub is the former leader of Jeunesses nationalistes révolutionnaires (JNR).'}
# CREATED REL: {'source': 'gremium_mc', 'target': 'gabriel_decouture', 'label': 'Member of', 'rationale': 'Gabriel Decouture is a member of Gremium MC.'}
# CREATED REL: {'source': 'black_shadow_north', 'target': 'gremium_mc', 'label': 'Supports', 'rationale': 'Black Shadow North is a supporter of Gremium MC.'}
# Iteration ended at 2023-12-19 14:55:06.957383, duration: 0:00:09.940817
# FILE: starting to process ./llm_responses/article-4_chunk-1.json
# Iteration started at 2023-12-19 14:55:06.958128
# CREATED ACTOR: Division Martel with DB ID 64
# RESOLVED ACTOR: Léo R. => Léo R.
# RESOLVED ACTOR: Mathis S. => Mathis D.
# CREATED REL: {'source': 'division_martel', 'target': 'leo_r', 'label': 'Member of', 'rationale': 'Léo R. is a member of Division Martel.'}
# CREATED REL: {'source': 'division_martel', 'target': 'mathis_s', 'label': 'Member of', 'rationale': 'Mathis S. is a member of Division Martel.'}
# Iteration ended at 2023-12-19 14:55:09.558811, duration: 0:00:02.600683
# FILE: starting to process ./llm_responses/article-29_chunk-1.json
# Iteration started at 2023-12-19 14:55:09.559752
# CREATED ACTOR: Laurent Jacob with DB ID 65
# CREATED ACTOR: Eric Zemmour with DB ID 66
# CREATED ACTOR: Denis Cieslik with DB ID 67
# CREATED ACTOR: Reconquête ! with DB ID 68
# CREATED REL: {'source': 'laurent_jacob', 'target': 'eric_zemmour', 'label': 'supported', 'rationale': 'Laurent Jacob supported Eric Zemmour in the last presidential campaign.'}
# CREATED REL: {'source': 'laurent_jacob', 'target': 'denis_cieslik', 'label': 'helped', 'rationale': 'Laurent Jacob helped Denis Cieslik during the presidential campaign.'}
# Iteration ended at 2023-12-19 14:55:12.624053, duration: 0:00:03.064301
# FILE: starting to process ./llm_responses/article-3_chunk-1.json
# Iteration started at 2023-12-19 14:55:12.624528
# CREATED ACTOR: Extrême droite with DB ID 69
# CREATED ACTOR: Identitaires du Rhône-Alpes with DB ID 70
# CREATED ACTOR: Remparts Lyon with DB ID 71
# CREATED ACTOR: Génération identitaire (GI) with DB ID 72
# CREATED ACTOR: La Traboule with DB ID 73
# CREATED ACTOR: Top Sport Rhône with DB ID 74
# CREATED ACTOR: L’Agogé with DB ID 75
# CREATED ACTOR: Jean-Yves Le Gallou with DB ID 76
# RESOLVED ACTOR: Stéphane Ravier => Stéphane Ravier
# RESOLVED ACTOR: Sinisha Milinov => Sinisha Milinov
# CREATED ACTOR: Adrien Ragot with DB ID 77
# CREATED ACTOR: Chloé with DB ID 78
# CREATED ACTOR: Adam with DB ID 79
# CREATED ACTOR: Roxane Chaudesaigues with DB ID 80
# CREATED ACTOR: Thibault L. with DB ID 81
# CREATED REL: {'source': 'extreme_droite', 'target': 'identitaires_du_rhonealpes', 'label': 'belongs to', 'rationale': 'The Identitaires du Rhône-Alpes belong to the far right.'}
# CREATED REL: {'source': 'extreme_droite', 'target': 'remparts_lyon', 'label': 'belongs to', 'rationale': 'Remparts Lyon belongs to the far right.'}
# CREATED REL: {'source': 'extreme_droite', 'target': 'generation_identitaire_gi', 'label': 'belongs to', 'rationale': 'Génération Identitaire (GI) belongs to the far right.'}
# CREATED REL: {'source': 'remparts_lyon', 'target': 'generation_identitaire_gi', 'label': 'succeeded', 'rationale': 'Remparts Lyon took over after the dissolution of Génération Identitaire (GI).'}
# CREATED REL: {'source': 'la_traboule', 'target': 'generation_identitaire_gi', 'label': 'was social headquarters of', 'rationale': 'La Traboule was the social headquarters of GI.'}
# CREATED REL: {'source': 'la_traboule', 'target': 'remparts_lyon', 'label': 'hosts activities of', 'rationale': 'La Traboule hosts activities of Remparts Lyon.'}
# CREATED REL: {'source': 'top_sport_rhone', 'target': 'lagoge', 'label': 'manages', 'rationale': 'Top Sport Rhône manages the L’Agogé boxing gym.'}
# CREATED REL: {'source': 'jeanyves_le_gallou', 'target': 'remparts_lyon', 'label': 'gave lectures at', 'rationale': 'Jean-Yves Le Gallou gave lectures at the Remparts.'}
# CREATED REL: {'source': 'stephane_ravier', 'target': 'remparts_lyon', 'label': 'spoke at', 'rationale': 'Stéphane Ravier spoke at the Remparts.'}
# CREATED REL: {'source': 'sinisha_milinov', 'target': 'generation_identitaire_gi', 'label': 'was militant of', 'rationale': 'Sinisha Milinov was a militant of GI.'}
# CREATED REL: {'source': 'sinisha_milinov', 'target': 'remparts_lyon', 'label': 'is spokesperson of', 'rationale': 'Sinisha Milinov is a spokesperson of the Remparts.'}
# CREATED REL: {'source': 'adrien_ragot', 'target': 'generation_identitaire_gi', 'label': 'was figure of', 'rationale': 'Adrien Ragot was a figure of GI.'}
# CREATED REL: {'source': 'adrien_ragot', 'target': 'remparts_lyon', 'label': 'is involved in', 'rationale': "Adrien Ragot is involved in the Remparts' activities."}
# CREATED REL: {'source': 'chloe', 'target': 'generation_identitaire_gi', 'label': 'was active in', 'rationale': 'Chloé was active in GI.'}
# CREATED REL: {'source': 'chloe', 'target': 'remparts_lyon', 'label': 'is active in', 'rationale': 'Chloé is active in the Remparts.'}
# CREATED REL: {'source': 'adam', 'target': 'generation_identitaire_gi', 'label': 'was active in', 'rationale': 'Adam was active in GI.'}
# CREATED REL: {'source': 'adam', 'target': 'remparts_lyon', 'label': 'is active in', 'rationale': 'Adam is active in the Remparts.'}
# CREATED REL: {'source': 'roxane_chaudesaigues', 'target': 'generation_identitaire_gi', 'label': 'was militant of', 'rationale': 'Roxane Chaudesaigues was a militant of GI.'}
# CREATED REL: {'source': 'thibault_l', 'target': 'generation_identitaire_gi', 'label': 'was militant of', 'rationale': 'Thibault L. was a militant of GI.'}
# Iteration ended at 2023-12-19 14:55:30.640084, duration: 0:00:18.015556
# FILE: starting to process ./llm_responses/article-7_chunk-3.json
# Iteration started at 2023-12-19 14:55:30.640968
# RESOLVED ACTOR: Clément Girard => Clément Girard
# CREATED ACTOR: RN with DB ID 82
# CREATED ACTOR: Action Française with DB ID 83
# RESOLVED ACTOR: RNJ => RNJ
# CREATED ACTOR: Aaron V. with DB ID 84
# CREATED ACTOR: Patria Albiges with DB ID 85
# CREATED ACTOR: MesOs with DB ID 86
# RESOLVED ACTOR: GUD => Gud
# RESOLVED ACTOR: Luc Lahalle => Luc Lahalle
# CREATED ACTOR: Pierre-Romain Thionnet with DB ID 87
# CREATED ACTOR: Frédéric Chatillon with DB ID 88
# CREATED ACTOR: Axel Loustau with DB ID 89
# RESOLVED ACTOR: Marine Le Pen => Marine Le Pen
# CREATED REL: {'source': 'clement_girard', 'target': 'rn', 'label': 'campaigns for', 'rationale': 'Clément Girard actively campaigns for RN in Fréjus and la Seyne-sur-Mer.'}
# CREATED REL: {'source': 'clement_girard', 'target': 'action_francaise', 'label': 'campaigns for', 'rationale': 'Clément Girard campaigns for Action Française in Avignon.'}
# CREATED REL: {'source': 'aaron_v', 'target': 'rnj', 'label': 'was active for', 'rationale': 'Aaron V. was very active for RNJ.'}
# CREATED REL: {'source': 'aaron_v', 'target': 'patria_albiges', 'label': 'was a member of', 'rationale': 'Aaron V. was a member of Patria Albiges.'}
# CREATED REL: {'source': 'gud', 'target': 'luc_lahalle', 'label': 'is a member of', 'rationale': 'Luc Lahalle is a member of GUD.'}
# CREATED REL: {'source': 'gud', 'target': 'pierreromain_thionnet', 'label': 'is a close associate of', 'rationale': 'Luc Lahalle is a close associate of Pierre-Romain Thionnet, the head of young RN.'}
# CREATED REL: {'source': 'pierreromain_thionnet', 'target': 'rn', 'label': 'is the head of', 'rationale': 'Pierre-Romain Thionnet is the head of young RN.'}
# CREATED REL: {'source': 'frederic_chatillon', 'target': 'marine_le_pen', 'label': 'is a friend of', 'rationale': 'Frédéric Chatillon is a friend of Marine Le Pen.'}
# CREATED REL: {'source': 'axel_loustau', 'target': 'marine_le_pen', 'label': 'is a friend of', 'rationale': 'Axel Loustau is a friend of Marine Le Pen.'}
# CREATED REL: {'source': 'marine_le_pen', 'target': 'rn', 'label': 'is a prominent figure in', 'rationale': 'Marine Le Pen is a prominent figure in the RN party.'}
# Iteration ended at 2023-12-19 14:55:43.859358, duration: 0:00:13.218390
# FILE: starting to process ./llm_responses/article-23_chunk-1.json
# Iteration started at 2023-12-19 14:55:43.859817
# Iteration ended at 2023-12-19 14:55:43.861185, duration: 0:00:00.001368
# FILE: starting to process ./llm_responses/article-10_chunk-2.json
# Iteration started at 2023-12-19 14:55:43.861323
# CREATED ACTOR: Division Martel with DB ID 90
# CREATED ACTOR: Groupe Union Défense (Gud) with DB ID 91
# CREATED ACTOR: Maxime L. with DB ID 92
# RESOLVED ACTOR: Léo R. => Léo R.
# CREATED REL: {'source': 'division_martel', 'target': 'groupe_union_defense_gud', 'label': 'Close to', 'rationale': 'The Division Martel is close to the Groupe Union Défense (Gud).'}
# CREATED REL: {'source': 'division_martel', 'target': 'maxime_l', 'label': 'Includes', 'rationale': 'The Division Martel includes Maxime L. as a member.'}
# CREATED REL: {'source': 'division_martel', 'target': 'leo_r', 'label': 'Includes', 'rationale': 'The Division Martel includes Léo R. as a leader.'}
# Iteration ended at 2023-12-19 14:55:47.937796, duration: 0:00:04.076473
# FILE: starting to process ./llm_responses/article-42_chunk-2.json
# Iteration started at 2023-12-19 14:55:47.938231
# Iteration ended at 2023-12-19 14:55:47.939702, duration: 0:00:00.001471
# FILE: starting to process ./llm_responses/article-17_chunk-2.json
# Iteration started at 2023-12-19 14:55:47.939897
# CREATED ACTOR: Arno Guibert with DB ID 93
# RESOLVED ACTOR: Alvarium => Alvarium
# CREATED ACTOR: Academia Christiana with DB ID 94
# RESOLVED ACTOR: Génération Identitaire => Génération identitaire
# CREATED REL: {'source': 'arno_guibert', 'target': 'alvarium', 'label': 'Member of', 'rationale': 'Arno Guibert was a former member of Alvarium.'}
# CREATED REL: {'source': 'arno_guibert', 'target': 'academia_christiana', 'label': 'Figure of', 'rationale': 'Arno Guibert is a figure of the Catholic movement Academia Christiana.'}
# CREATED REL: {'source': 'arno_guibert', 'target': 'generation_identitaire', 'label': 'Spoke at event organized by', 'rationale': 'Arno Guibert spoke on behalf of Academia Christiana at a protest against Islamists organized by Génération Identitaire in 2019.'}
# Iteration ended at 2023-12-19 14:55:53.075474, duration: 0:00:05.135577
# FILE: starting to process ./llm_responses/article-36_chunk-1.json
# Iteration started at 2023-12-19 14:55:53.075943
# CREATED ACTOR: Faits & Documents with DB ID 95
# CREATED ACTOR: Emmanuel Ratier with DB ID 96
# CREATED ACTOR: Alain Soral with DB ID 97
# CREATED ACTOR: Kontre Kulture with DB ID 98
# CREATED ACTOR: Vincent Moysan with DB ID 99
# CREATED ACTOR: Xavier Poussard with DB ID 100
# CREATED ACTOR: Edition et Documentation parisienne with DB ID 101
# CREATED ACTOR: Culture pour Tous with DB ID 102
# CREATED ACTOR: Soralie with DB ID 103
# CREATED ACTOR: Rivarol with DB ID 104
# CREATED ACTOR: Henry Coston with DB ID 105
# CREATED ACTOR: clan Le Pen with DB ID 106
# CREATED REL: {'source': 'faits__documents', 'target': 'emmanuel_ratier', 'label': 'founded by', 'rationale': 'Faits & Documents was founded by Emmanuel Ratier.'}
# CREATED REL: {'source': 'faits__documents', 'target': 'alain_soral', 'label': 'associated with', 'rationale': 'Faits & Documents is associated with Alain Soral.'}
# CREATED REL: {'source': 'faits__documents', 'target': 'kontre_kulture', 'label': 'associated with', 'rationale': 'Faits & Documents is associated with Kontre Kulture.'}
# CREATED REL: {'source': 'faits__documents', 'target': 'vincent_moysan', 'label': 'taken over by', 'rationale': "Faits & Documents was taken over by Vincent Moysan after Emmanuel Ratier's death."}
# CREATED REL: {'source': 'faits__documents', 'target': 'xavier_poussard', 'label': 'taken over by', 'rationale': "Faits & Documents was taken over by Xavier Poussard after Emmanuel Ratier's death."}
# CREATED REL: {'source': 'emmanuel_ratier', 'target': 'alain_soral', 'label': 'associated with', 'rationale': 'Emmanuel Ratier was associated with Alain Soral.'}
# CREATED REL: {'source': 'emmanuel_ratier', 'target': 'kontre_kulture', 'label': 'associated with', 'rationale': 'Emmanuel Ratier was associated with Kontre Kulture.'}
# CREATED REL: {'source': 'emmanuel_ratier', 'target': 'henry_coston', 'label': 'disciple of', 'rationale': 'Emmanuel Ratier was a disciple of Henry Coston.'}
# CREATED REL: {'source': 'alain_soral', 'target': 'kontre_kulture', 'label': 'owns', 'rationale': 'Alain Soral owns Kontre Kulture.'}
# CREATED REL: {'source': 'vincent_moysan', 'target': 'emmanuel_ratier', 'label': 'associated with', 'rationale': 'Vincent Moysan was associated with Emmanuel Ratier.'}
# CREATED REL: {'source': 'vincent_moysan', 'target': 'alain_soral', 'label': 'associated with', 'rationale': 'Vincent Moysan was associated with Alain Soral.'}
# CREATED REL: {'source': 'xavier_poussard', 'target': 'emmanuel_ratier', 'label': 'associated with', 'rationale': 'Xavier Poussard was associated with Emmanuel Ratier.'}
# CREATED REL: {'source': 'xavier_poussard', 'target': 'alain_soral', 'label': 'associated with', 'rationale': 'Xavier Poussard was associated with Alain Soral.'}
# CREATED REL: {'source': 'edition_et_documentation_parisienne', 'target': 'faits__documents', 'label': 'publishes', 'rationale': 'Edition et Documentation parisienne publishes Faits & Documents.'}
# CREATED REL: {'source': 'edition_et_documentation_parisienne', 'target': 'culture_pour_tous', 'label': 'owns business of', 'rationale': 'Edition et Documentation parisienne owns the business of Culture pour Tous.'}
# CREATED REL: {'source': 'culture_pour_tous', 'target': 'soralie', 'label': 'flagship of', 'rationale': 'Culture pour Tous is a flagship of Soralie.'}
# Iteration ended at 2023-12-19 14:56:08.948532, duration: 0:00:15.872589
# FILE: starting to process ./llm_responses/article-31_chunk-1.json
# Iteration started at 2023-12-19 14:56:08.949076
# CREATED ACTOR: César A. with DB ID 107
# Iteration ended at 2023-12-19 14:56:09.442242, duration: 0:00:00.493166
# FILE: starting to process ./llm_responses/article-34_chunk-2.json
# Iteration started at 2023-12-19 14:56:09.442457
# CREATED ACTOR: Les vilains fachos (LVF) with DB ID 108
# CREATED ACTOR: Aurora with DB ID 109
# RESOLVED ACTOR: Léo => Léo R.
# CREATED ACTOR: Théo.C with DB ID 110
# CREATED ACTOR: Henri.T with DB ID 111
# RESOLVED ACTOR: Génération Identitaire => Génération identitaire
# RESOLVED ACTOR: Argos => Argos
# CREATED REL: {'source': 'aurora', 'target': 'leo', 'label': 'led by', 'rationale': 'Léo is the leader of Aurora.'}
# CREATED REL: {'source': 'aurora', 'target': 'theoc', 'label': 'includes', 'rationale': "Théo.C is one of Léo's lieutenants in the hard core of the Aurora group."}
# CREATED REL: {'source': 'aurora', 'target': 'henrit', 'label': 'includes', 'rationale': "Henri.T is one of Léo's lieutenants in the hard core of the Aurora group."}
# CREATED REL: {'source': 'theoc', 'target': 'argos', 'label': 'member of', 'rationale': 'Théo.C claims to be a member of the Argos project.'}
# CREATED REL: {'source': 'henrit', 'target': 'argos', 'label': 'member of', 'rationale': 'Henri.T claims to be a member of the Argos project.'}
# Iteration ended at 2023-12-19 14:56:15.914002, duration: 0:00:06.471545
# FILE: starting to process ./llm_responses/article-15_chunk-1.json
# Iteration started at 2023-12-19 14:56:15.914424
# CREATED ACTOR: Civitas with DB ID 112
# CREATED ACTOR: Alain Escada with DB ID 113
# CREATED ACTOR: Pierre Hillard with DB ID 114
# CREATED ACTOR: Gilles Martin with DB ID 115
# CREATED ACTOR: Nicolas Hrovatin with DB ID 116
# RESOLVED ACTOR: Rivarol => Rivarol
# CREATED REL: {'source': 'civitas', 'target': 'alain_escada', 'label': 'led by', 'rationale': 'Alain Escada is the leader of Civitas.'}
# CREATED REL: {'source': 'civitas', 'target': 'pierre_hillard', 'label': 'associated with', 'rationale': 'Pierre Hillard made an anti-Semitic speech at a Civitas event.'}
# CREATED REL: {'source': 'civitas', 'target': 'gilles_martin', 'label': 'represented by', 'rationale': 'Gilles Martin is a representative of Civitas.'}
# CREATED REL: {'source': 'civitas', 'target': 'nicolas_hrovatin', 'label': 'represented by', 'rationale': 'Nicolas Hrovatin is a representative of Civitas.'}
# CREATED REL: {'source': 'civitas', 'target': 'rivarol', 'label': 'supported by', 'rationale': 'Rivarol supports Civitas.'}
# Iteration ended at 2023-12-19 14:56:21.958212, duration: 0:00:06.043788
# FILE: starting to process ./llm_responses/article-40_chunk-1.json
# Iteration started at 2023-12-19 14:56:21.958687
# RESOLVED ACTOR: Julien C. => Julien Chmielewski
# CREATED ACTOR: Barjols with DB ID 117
# CREATED ACTOR: Jérôme T. with DB ID 118
# RESOLVED ACTOR: Denis C. => Denis Cieslik
# CREATED ACTOR: RN en Moselle with DB ID 119
# CREATED REL: {'source': 'julien_c', 'target': 'barjols', 'label': 'Member of', 'rationale': 'Julien C. is accused of being a member of the Barjols.'}
# CREATED REL: {'source': 'julien_c', 'target': 'denis_c', 'label': 'Provided plans to', 'rationale': 'Julien C. provided Denis C. with plans for explosives.'}
# CREATED REL: {'source': 'jerome_t', 'target': 'barjols', 'label': 'Member of', 'rationale': 'Jérôme T. is accused of being a member of the Barjols.'}
# CREATED REL: {'source': 'denis_c', 'target': 'barjols', 'label': 'Leader of', 'rationale': 'Denis C. is the leader of the Barjols.'}
# CREATED REL: {'source': 'denis_c', 'target': 'rn_en_moselle', 'label': 'Former member of', 'rationale': 'Denis C. was formerly a part of the RN in Moselle.'}
# Iteration ended at 2023-12-19 14:56:27.496330, duration: 0:00:05.537643
# FILE: starting to process ./llm_responses/article-12_chunk-1.json
# Iteration started at 2023-12-19 14:56:27.496682
# CREATED ACTOR: C9M with DB ID 120
# RESOLVED ACTOR: Marc de Cacqueray => Marc de Cacqueray-Valmenier
# RESOLVED ACTOR: Gud => Gud
# CREATED ACTOR: division Martel with DB ID 121
# RESOLVED ACTOR: Action française => Action Française
# CREATED ACTOR: Zouaves with DB ID 122
# RESOLVED ACTOR: Frédéric Chatillon => Frédéric Chatillon
# RESOLVED ACTOR: Axel Loustau => Axel Loustau
# RESOLVED ACTOR: RN => RN
# RESOLVED ACTOR: Marine Le Pen => Marine Le Pen
# CREATED ACTOR: Gabriel Loustau with DB ID 123
# RESOLVED ACTOR: César => César A.
# CREATED ACTOR: Paul with DB ID 124
# CREATED REL: {'source': 'marc_de_cacqueray', 'target': 'gud', 'label': 'leads', 'rationale': 'Marc de Cacqueray leads Gud.'}
# CREATED REL: {'source': 'marc_de_cacqueray', 'target': 'division_martel', 'label': 'mentors', 'rationale': 'Marc de Cacqueray mentors the division Martel.'}
# CREATED REL: {'source': 'marc_de_cacqueray', 'target': 'action_francaise', 'label': 'involved in', 'rationale': 'Marc de Cacqueray was involved in Action française.'}
# CREATED REL: {'source': 'marc_de_cacqueray', 'target': 'zouaves', 'label': 'involved in', 'rationale': 'Marc de Cacqueray was involved in Zouaves.'}
# CREATED REL: {'source': 'frederic_chatillon', 'target': 'rn', 'label': 'linked to', 'rationale': 'Frédéric Chatillon is linked to RN.'}
# CREATED REL: {'source': 'axel_loustau', 'target': 'rn', 'label': 'linked to', 'rationale': 'Axel Loustau is linked to RN.'}
# RESOLVED REL: {'source': 'frederic_chatillon', 'target': 'marine_le_pen', 'label': 'linked to', 'rationale': 'Frédéric Chatillon is linked to Marine Le Pen.'} resolved to (75, 88, 57, 'is a friend of', 'Frédéric Chatillon is a friend of Marine Le Pen.')
# RESOLVED REL: {'source': 'axel_loustau', 'target': 'marine_le_pen', 'label': 'linked to', 'rationale': 'Axel Loustau is linked to Marine Le Pen.'} resolved to (76, 89, 57, 'is a friend of', 'Axel Loustau is a friend of Marine Le Pen.')
# CREATED REL: {'source': 'gabriel_loustau', 'target': 'gud', 'label': 'is a lieutenant in', 'rationale': 'Gabriel Loustau is a lieutenant in Gud.'}
# Iteration ended at 2023-12-19 14:56:39.334736, duration: 0:00:11.838054
# FILE: starting to process ./llm_responses/article-16_chunk-2.json
# Iteration started at 2023-12-19 14:56:39.335231
# CREATED ACTOR: Audace with DB ID 125
# CREATED ACTOR: Lyon Populaire with DB ID 126
# CREATED ACTOR: Eliot Bertin with DB ID 127
# CREATED ACTOR: Marc de Cacqueray-Valménier with DB ID 128
# CREATED ACTOR: cercle de réflexion François Duprat with DB ID 129
# CREATED ACTOR: Gabriele Adinolfi with DB ID 130
# RESOLVED ACTOR: Gud => Gud
# RESOLVED ACTOR: Academia Christiana => Academia Christiana
# CREATED ACTOR: 'Touche pas à ma statue' with DB ID 131
# CREATED ACTOR: Reconquête Isabelle Surply with DB ID 132
# RESOLVED ACTOR: Génération Identitaire => Génération identitaire
# RESOLVED ACTOR: La Traboule => La Traboule
# RESOLVED ACTOR: Remparts => Remparts Lyon
# CREATED ACTOR: Le 7.59 with DB ID 133
# CREATED ACTOR: L’Agogé with DB ID 134
# RESOLVED ACTOR: Sinisha Milinov => Sinisha Milinov
# CREATED ACTOR: Marchons Enfants with DB ID 135
# CREATED ACTOR: Manif pour Tous with DB ID 136
# CREATED ACTOR: Aliette Espieux with DB ID 137
# RESOLVED ACTOR: Rassemblement National => Rassemblement national
# CREATED REL: {'source': 'eliot_bertin', 'target': 'lyon_populaire', 'label': 'Leads', 'rationale': 'Eliot Bertin leads Lyon Populaire.'}
# CREATED REL: {'source': 'eliot_bertin', 'target': 'cercle_de_reflexion_francois_duprat', 'label': 'Launched', 'rationale': "Eliot Bertin launched the 'cercle de réflexion François Duprat'."}
# CREATED REL: {'source': 'eliot_bertin', 'target': 'generation_identitaire', 'label': 'Associated with', 'rationale': 'Eliot Bertin is associated with Génération Identitaire.'}
# CREATED REL: {'source': 'eliot_bertin', 'target': 'la_traboule', 'label': 'Frequents', 'rationale': "Eliot Bertin frequents the bar 'La Traboule'."}
# CREATED REL: {'source': 'eliot_bertin', 'target': 'lagoge', 'label': 'Promotes', 'rationale': "Eliot Bertin promotes the boxing gym 'L’Agogé'."}
# CREATED REL: {'source': 'eliot_bertin', 'target': 'marchons_enfants', 'label': 'Mobilizes with', 'rationale': 'Eliot Bertin mobilizes with the collective Marchons Enfants.'}
# CREATED REL: {'source': 'gabriele_adinolfi', 'target': 'lyon_populaire', 'label': 'Attended conference', 'rationale': 'Gabriele Adinolfi attended a conference organized by Lyon Populaire.'}
# CREATED REL: {'source': 'gud', 'target': 'lyon_populaire', 'label': 'Attended forum', 'rationale': 'Gud attended a forum organized by Lyon Populaire.'}
# CREATED REL: {'source': 'academia_christiana', 'target': 'lyon_populaire', 'label': 'Attended forum', 'rationale': 'Academia Christiana attended a forum organized by Lyon Populaire.'}
# CREATED REL: {'source': 'touche_pas_a_ma_statue', 'target': 'lyon_populaire', 'label': 'Attended forum', 'rationale': "'Touche pas à ma statue' attended a forum organized by Lyon Populaire."}
# CREATED REL: {'source': 'reconquete_isabelle_surply', 'target': 'lyon_populaire', 'label': 'Attended forum', 'rationale': 'Reconquête Isabelle Surply attended a forum organized by Lyon Populaire.'}
# RESOLVED REL: {'source': 'la_traboule', 'target': 'remparts', 'label': 'Used by', 'rationale': 'La Traboule is used by the Remparts.'} resolved to (54, 73, 71, 'hosts activities of', 'La Traboule hosts activities of Remparts Lyon.')
# CREATED REL: {'source': 'le_759', 'target': 'eliot_bertin', 'label': 'Hosted conference', 'rationale': 'Le 7.59 hosted a conference given by Eliot Bertin.'}
# RESOLVED REL: {'source': 'sinisha_milinov', 'target': 'remparts', 'label': 'Spokesperson for', 'rationale': 'Sinisha Milinov is a spokesperson for Remparts.'} resolved to (59, 13, 71, 'is spokesperson of', 'Sinisha Milinov is a spokesperson of the Remparts.')
# CREATED REL: {'source': 'aliette_espieux', 'target': 'rassemblement_national', 'label': 'Candidate for', 'rationale': 'Aliette Espieux is a candidate for the National Rally in the fifth district of Lyon.'}
# CREATED REL: {'source': 'aliette_espieux', 'target': 'lyon_populaire', 'label': 'Relays actions of', 'rationale': 'Aliette Espieux relays the actions of Lyon Populaire on social media.'}
# Iteration ended at 2023-12-19 14:57:05.376733, duration: 0:00:26.041502
# FILE: starting to process ./llm_responses/article-11_chunk-2.json
# Iteration started at 2023-12-19 14:57:05.377219
# CREATED ACTOR: LDJ with DB ID 138
# CREATED ACTOR: Marie-Christine Arnautu with DB ID 139
# RESOLVED ACTOR: Marine le Pen => Marine Le Pen
# RESOLVED ACTOR: Alain Soral => Alain Soral
# CREATED ACTOR: Bloc Identitaire with DB ID 140
# CREATED ACTOR: Riposte Laïque with DB ID 141
# CREATED REL: {'source': 'ldj', 'target': 'mariechristine_arnautu', 'label': 'Integration', 'rationale': 'The LDJ integrated Marie-Christine Arnautu into a demonstration.'}
# CREATED REL: {'source': 'marine_le_pen', 'target': 'alain_soral', 'label': 'Protection', 'rationale': 'Marine le Pen asked the LDJ to stop attacking Alain Soral.'}
# CREATED REL: {'source': 'bloc_identitaire', 'target': 'riposte_laique', 'label': 'Collaboration', 'rationale': 'Bloc Identitaire and Riposte Laïque organized a meeting against Islamization together in 2010.'}
# Iteration ended at 2023-12-19 14:57:10.514652, duration: 0:00:05.137433
# FILE: starting to process ./llm_responses/article-30_chunk-1.json
# Iteration started at 2023-12-19 14:57:10.515113
# CREATED ACTOR: Comité du 9 mai with DB ID 142
# RESOLVED ACTOR: Gud => Gud
# CREATED ACTOR: Zouaves Paris with DB ID 143
# CREATED ACTOR: FN with DB ID 144
# RESOLVED ACTOR: Marine Le Pen => Marine Le Pen
# RESOLVED ACTOR: Frédéric Chatillon => Frédéric Chatillon
# RESOLVED ACTOR: Axel Loustau => Axel Loustau
# CREATED REL: {'source': 'gud', 'target': 'fn', 'label': 'Link', 'rationale': 'Gud has always had a link with FN.'}
# CREATED REL: {'source': 'gud', 'target': 'marine_le_pen', 'label': 'Association', 'rationale': 'Former Gud figures are found around Marine Le Pen.'}
# CREATED REL: {'source': 'gud', 'target': 'frederic_chatillon', 'label': 'Former Executive', 'rationale': 'Frédéric Chatillon is a former Gud executive who remains a supplier of the far-right party.'}
# CREATED REL: {'source': 'gud', 'target': 'axel_loustau', 'label': 'Former Executive', 'rationale': 'Axel Loustau is a former Gud executive who remains a supplier of the far-right party.'}
# Iteration ended at 2023-12-19 14:57:16.902310, duration: 0:00:06.387197
# FILE: starting to process ./llm_responses/article-37_chunk-1.json
# Iteration started at 2023-12-19 14:57:16.902731
# RESOLVED ACTOR: extrême droite => Extrême droite
# CREATED ACTOR: néonazis with DB ID 145
# RESOLVED ACTOR: Front national de la jeunesse => Rassemblement national
# RESOLVED ACTOR: Gud => Gud
# RESOLVED ACTOR: Rassemblement national => Rassemblement national
# CREATED ACTOR: RNJ 51 with DB ID 146
# CREATED ACTOR: Théo V. with DB ID 147
# RESOLVED ACTOR: MesOs => MesOs
# CREATED ACTOR: Alex T. with DB ID 148
# RESOLVED ACTOR: Marine Le Pen => Marine Le Pen
# CREATED ACTOR: Jordan Bardella with DB ID 149
# CREATED REL: {'source': 'extreme_droite', 'target': 'neonazis', 'label': 'utilise', 'rationale': "L'extrême droite utilise les néonazis pour coller des affiches."}
# CREATED REL: {'source': 'front_national_de_la_jeunesse', 'target': 'gud', 'label': 'utilise', 'rationale': 'Le Front national de la jeunesse utilisait le Gud pour les accompagner.'}
# CREATED REL: {'source': 'rnj_51', 'target': 'theo_v', 'label': 'publie', 'rationale': 'RNJ 51 a publié un selfie avec Théo V., un hooligan néonazi.'}
# CREATED REL: {'source': 'rnj_51', 'target': 'alex_t', 'label': 'publie', 'rationale': 'RNJ 51 a publié un selfie avec Alex T., un hooligan néonazi.'}
# CREATED REL: {'source': 'mesos', 'target': 'rassemblement_national', 'label': 'collabore', 'rationale': 'Les MesOs, un groupe de hooligans néonazis, ont participé à des collages avec les militants du Rassemblement national.'}
# Iteration ended at 2023-12-19 14:57:26.166644, duration: 0:00:09.263913
# FILE: starting to process ./llm_responses/article-22_chunk-1.json
# Iteration started at 2023-12-19 14:57:26.167159
# CREATED ACTOR: Lukas C. with DB ID 150
# RESOLVED ACTOR: Raphaël G. => Raphaël Ayma
# RESOLVED ACTOR: Vandal Besak => Vandal Besak
# CREATED REL: {'source': 'lukas_c', 'target': 'vandal_besak', 'label': 'Membership', 'rationale': 'Lukas C. is a member of the violent far-right group Vandal Besak.'}
# CREATED REL: {'source': 'raphael_g', 'target': 'vandal_besak', 'label': 'Membership', 'rationale': 'Raphaël G. is a member of the violent far-right group Vandal Besak.'}
# Iteration ended at 2023-12-19 14:57:30.298686, duration: 0:00:04.131527
# FILE: starting to process ./llm_responses/article-25_chunk-1.json
# Iteration started at 2023-12-19 14:57:30.299107
# RESOLVED ACTOR: Civitas => Civitas
# CREATED ACTOR: La Dissidence française with DB ID 151
# CREATED ACTOR: La Ligue du Midi with DB ID 152
# RESOLVED ACTOR: Alain Escada => Alain Escada
# CREATED ACTOR: Vincent Vauclin with DB ID 153
# CREATED ACTOR: Mouvement national-démocrate with DB ID 154
# RESOLVED ACTOR: Eric Zemmour => Eric Zemmour
# CREATED ACTOR: Les Nationalistes d’Yvan Benedetti with DB ID 155
# RESOLVED ACTOR: Action française => Action Française
# CREATED ACTOR: Clément Gautier with DB ID 156
# CREATED ACTOR: Sébastien de Kerrero with DB ID 157
# RESOLVED ACTOR: Soral => Alain Soral
# CREATED ACTOR: Parti de la France with DB ID 158
# CREATED ACTOR: Thomas Joly with DB ID 159
# CREATED ACTOR: Yvan Benedetti with DB ID 160
# CREATED REL: {'source': 'civitas', 'target': 'la_dissidence_francaise', 'label': 'coalition', 'rationale': 'Civitas formed a coalition with La Dissidence française for the municipal elections.'}
# CREATED REL: {'source': 'civitas', 'target': 'la_ligue_du_midi', 'label': 'coalition', 'rationale': 'Civitas formed a coalition with La Ligue du Midi for the municipal elections.'}
# RESOLVED REL: {'source': 'civitas', 'target': 'alain_escada', 'label': 'leadership', 'rationale': 'Alain Escada is the president of Civitas.'} resolved to (105, 112, 113, 'led by', 'Alain Escada is the leader of Civitas.')
# CREATED REL: {'source': 'la_dissidence_francaise', 'target': 'vincent_vauclin', 'label': 'leadership', 'rationale': 'Vincent Vauclin was the leader of La Dissidence française.'}
# CREATED REL: {'source': 'la_ligue_du_midi', 'target': 'eric_zemmour', 'label': 'support', 'rationale': 'La Ligue du Midi supported Eric Zemmour in the presidential campaign.'}
# CREATED REL: {'source': 'civitas', 'target': 'les_nationalistes_dyvan_benedetti', 'label': 'coalition', 'rationale': 'Civitas formed a coalition with Les Nationalistes d’Yvan Benedetti for the municipal elections.'}
# CREATED REL: {'source': 'action_francaise', 'target': 'clement_gautier', 'label': 'split', 'rationale': 'A faction led by Clément Gautier split off from Action française.'}
# CREATED REL: {'source': 'sebastien_de_kerrero', 'target': 'soral', 'label': 'former_association', 'rationale': 'Sébastien de Kerrero, also known as Monsieur K, was formerly associated with Soral.'}
# CREATED REL: {'source': 'civitas', 'target': 'parti_de_la_france', 'label': 'potential_alliance', 'rationale': 'Alain Escada mentioned Parti de la France as a potential ally.'}
# CREATED REL: {'source': 'parti_de_la_france', 'target': 'thomas_joly', 'label': 'membership', 'rationale': 'Thomas Joly is a member of Parti de la France.'}
# CREATED REL: {'source': 'les_nationalistes_dyvan_benedetti', 'target': 'yvan_benedetti', 'label': 'leadership', 'rationale': 'Yvan Benedetti is the leader of Les Nationalistes d’Yvan Benedetti.'}
# Iteration ended at 2023-12-19 14:57:45.866738, duration: 0:00:15.567631
# FILE: starting to process ./llm_responses/article-8_chunk-1.json
# Iteration started at 2023-12-19 14:57:45.867204
# CREATED ACTOR: L’extrême droite radicale with DB ID 161
# CREATED ACTOR: groupe local identitaire Les Remparts with DB ID 162
# RESOLVED ACTOR: Chloé => Chloé
# RESOLVED ACTOR: Adam A. => Adam
# CREATED ACTOR: Asla with DB ID 163
# RESOLVED ACTOR: Roxane Chaudesaigues => Roxane Chaudesaigues
# CREATED ACTOR: Front national with DB ID 164
# CREATED ACTOR: Laurent Obertone with DB ID 165
# CREATED REL: {'source': 'lextreme_droite_radicale', 'target': 'groupe_local_identitaire_les_remparts', 'label': 'includes', 'rationale': 'The radical right includes the groupe local identitaire Les Remparts.'}
# CREATED REL: {'source': 'chloe', 'target': 'asla', 'label': 'supported by', 'rationale': 'Chloé is being supported by Asla.'}
# CREATED REL: {'source': 'adam_a', 'target': 'asla', 'label': 'supported by', 'rationale': 'Adam A. is being supported by Asla.'}
# CREATED REL: {'source': 'roxane_chaudesaigues', 'target': 'front_national', 'label': 'was a candidate for', 'rationale': 'Roxane Chaudesaigues was a candidate for the Front national.'}
# Iteration ended at 2023-12-19 14:57:53.303582, duration: 0:00:07.436378
# FILE: starting to process ./llm_responses/article-35_chunk-2.json
# Iteration started at 2023-12-19 14:57:53.304026
# CREATED ACTOR: Riwal communications with DB ID 166
# RESOLVED ACTOR: Frédéric Chatillon => Frédéric Chatillon
# RESOLVED ACTOR: Axel Loustau => Axel Loustau
# RESOLVED ACTOR: Marine Le Pen => Marine Le Pen
# RESOLVED ACTOR: Faits & Documents => Faits & Documents
# CREATED ACTOR: Alain Bonnet with DB ID 167
# CREATED REL: {'source': 'riwal_communications', 'target': 'frederic_chatillon', 'label': 'Co-Founders', 'rationale': 'Frédéric Chatillon and Axel Loustau co-founded Riwal communications.'}
# CREATED REL: {'source': 'riwal_communications', 'target': 'axel_loustau', 'label': 'Co-Founders', 'rationale': 'Axel Loustau and Frédéric Chatillon co-founded Riwal communications.'}
# RESOLVED REL: {'source': 'frederic_chatillon', 'target': 'marine_le_pen', 'label': 'Friends', 'rationale': 'Frédéric Chatillon is a childhood friend of Marine Le Pen.'} resolved to (75, 88, 57, 'is a friend of', 'Frédéric Chatillon is a friend of Marine Le Pen.')
# RESOLVED REL: {'source': 'axel_loustau', 'target': 'marine_le_pen', 'label': 'Friends', 'rationale': 'Axel Loustau is a childhood friend of Marine Le Pen.'} resolved to (76, 89, 57, 'is a friend of', 'Axel Loustau is a friend of Marine Le Pen.')
# CREATED REL: {'source': 'riwal_communications', 'target': 'faits__documents', 'label': 'Service Provider-Client', 'rationale': "Riwal communications has been designing the layout for 'Faits & Documents' for years."}
# Iteration ended at 2023-12-19 14:57:58.831170, duration: 0:00:05.527144
# FILE: starting to process ./llm_responses/article-32_chunk-2.json
# Iteration started at 2023-12-19 14:57:58.831538
# CREATED ACTOR: Identitaires with DB ID 168
# CREATED ACTOR: Nationalistes-révolutionnaires with DB ID 169
# CREATED ACTOR: Traditional extreme right with DB ID 170
# CREATED ACTOR: GI with DB ID 171
# CREATED ACTOR: François Duprat with DB ID 172
# RESOLVED ACTOR: Gud => Gud
# RESOLVED ACTOR: Neonazis => néonazis
# CREATED REL: {'source': 'identitaires', 'target': 'traditional_extreme_right', 'label': 'Distancing', 'rationale': 'Identitaires try to distance themselves from the traditional extreme right.'}
# Iteration ended at 2023-12-19 14:58:03.338945, duration: 0:00:04.507407
# FILE: starting to process ./llm_responses/article-41_chunk-1.json
# Iteration started at 2023-12-19 14:58:03.339601
# CREATED ACTOR: Yves Alphé with DB ID 173
# CREATED ACTOR: François-Xavier Gicquel with DB ID 174
# ...
# CREATED REL: {'source': 'notre_dame_dorveau', 'target': 'academia_christiana', 'label': 'établissement-organisation', 'rationale': "Notre Dame d’Orveau a accueilli un événement de l'Academia Christiana."}
# CREATED REL: {'source': 'notre_dame_dorveau', 'target': 'victor_aubert', 'label': 'établissement-ancien élève', 'rationale': 'Victor Aubert est un ancien élève de Notre Dame d’Orveau.'}
# CREATED REL: {'source': 'notre_dame_dorveau', 'target': 'zouaves', 'label': 'établissement-groupuscule', 'rationale': 'Des anciens élèves de Notre Dame d’Orveau ont rejoint le groupuscule Zouaves.'}
# CREATED REL: {'source': 'notre_dame_dorveau', 'target': 'alvarium', 'label': 'établissement-groupuscule', 'rationale': 'Des anciens élèves de Notre Dame d’Orveau ont rejoint le groupuscule Alvarium.'}
# CREATED REL: {'source': 'zouaves', 'target': 'paulalexis_husak', 'label': 'groupuscule-membre', 'rationale': 'Paul-Alexis Husak est un membre du groupuscule Zouaves.'}
# CREATED REL: {'source': 'alvarium', 'target': 'paulalexis_husak', 'label': 'groupuscule-membre', 'rationale': 'Paul-Alexis Husak est un membre du groupuscule Alvarium.'}
# Iteration ended at 2023-12-19 15:01:15.855234, duration: 0:00:11.757912
# FILE: starting to process ./llm_responses/article-29_chunk-2.json
# Iteration started at 2023-12-19 15:01:15.855682
# RESOLVED ACTOR: Marine Le Pen => Marine Le Pen
# RESOLVED ACTOR: Éric Zemmour => Eric Zemmour
# Iteration ended at 2023-12-19 15:01:17.024467, duration: 0:00:01.168785
# FILE: starting to process ./llm_responses/article-3_chunk-2.json
# Iteration started at 2023-12-19 15:01:17.024841
# RESOLVED ACTOR: Génération identitaire => Génération identitaire
# RESOLVED ACTOR: Traboule => La Traboule
# CREATED ACTOR: radicaux lyonnais with DB ID 280
# RESOLVED ACTOR: Adrien Ragot => Adrien Ragot
# CREATED ACTOR: Les Remparts with DB ID 281
# RESOLVED ACTOR: Guignol Squad => Guignol squad
# RESOLVED ACTOR: Remparts Lyon => Remparts Lyon
# CREATED ACTOR: Lugdunum Suum with DB ID 282
# RESOLVED ACTOR: identitaires => Identitaires
# RESOLVED ACTOR: Sinisha Milinov => Sinisha Milinov
# CREATED ACTOR: porte-parole des Remparts with DB ID 283
# CREATED REL: {'source': 'generation_identitaire', 'target': 'les_remparts', 'label': 'Influence', 'rationale': 'Les Remparts continue the themes dear to Génération identitaire'}
# CREATED REL: {'source': 'les_remparts', 'target': 'guignol_squad', 'label': 'Collaboration', 'rationale': 'Members of Les Remparts participated in actions of Guignol Squad'}
# CREATED REL: {'source': 'porteparole_des_remparts', 'target': 'les_remparts', 'label': 'Representation', 'rationale': 'Porte-parole des Remparts represents Les Remparts'}
# Iteration ended at 2023-12-19 15:01:28.141995, duration: 0:00:11.117154
# FILE: starting to process ./llm_responses/article-39_chunk-1.json
# Iteration started at 2023-12-19 15:01:28.142580
# CREATED ACTOR: Gud Paris with DB ID 284
# CREATED ACTOR: Luminis with DB ID 285
# RESOLVED ACTOR: Division Martel => Martel division
# CREATED ACTOR: Auctorum with DB ID 286
# RESOLVED ACTOR: Zouaves Paris => Zouaves Paris
# RESOLVED ACTOR: Marc de Cacqueray-Valménier => Marc de Cacqueray-Valmenier
# CREATED ACTOR: Loïk Le Priol with DB ID 287
# CREATED ACTOR: Romain Bouvier with DB ID 288
# RESOLVED ACTOR: Action Française => Action Française
# RESOLVED ACTOR: Eric Zemmour => Eric Zemmour
# RESOLVED ACTOR: Guignol squad => Guignol squad
# CREATED ACTOR: Lagaf’ crew with DB ID 289
# CREATED ACTOR: Gargouilles with DB ID 290
# CREATED ACTOR: Zoulous Nice with DB ID 291
# CREATED REL: {'source': 'gud_paris', 'target': 'luminis', 'label': 'Collaboration', 'rationale': 'Gud Paris and Luminis collaborate in organizing combat training sessions.'}
# CREATED REL: {'source': 'gud_paris', 'target': 'division_martel', 'label': 'Collaboration', 'rationale': 'Gud Paris and Division Martel collaborate in organizing combat training sessions.'}
# CREATED REL: {'source': 'gud_paris', 'target': 'auctorum', 'label': 'Collaboration', 'rationale': 'Gud Paris and Auctorum collaborate in organizing combat training sessions.'}
# CREATED REL: {'source': 'gud_paris', 'target': 'zouaves_paris', 'label': 'Succession', 'rationale': 'Zouaves Paris emerged from the dissolution of Gud Paris.'}
# CREATED REL: {'source': 'zouaves_paris', 'target': 'marc_de_cacquerayvalmenier', 'label': 'Leadership', 'rationale': 'Marc de Cacqueray-Valménier leads Zouaves Paris.'}
# CREATED REL: {'source': 'gud_paris', 'target': 'loik_le_priol', 'label': 'Membership', 'rationale': 'Loïk Le Priol is a member of Gud Paris.'}
# CREATED REL: {'source': 'gud_paris', 'target': 'romain_bouvier', 'label': 'Membership', 'rationale': 'Romain Bouvier is a member of Gud Paris.'}
# CREATED REL: {'source': 'zouaves_paris', 'target': 'action_francaise', 'label': 'Membership', 'rationale': 'Some members of Action Française joined Zouaves Paris.'}
# CREATED REL: {'source': 'guignol_squad', 'target': 'zouaves_paris', 'label': 'Similarity', 'rationale': 'Guignol squad is similar to Zouaves Paris.'}
# CREATED REL: {'source': 'lagaf_crew', 'target': 'zouaves_paris', 'label': 'Similarity', 'rationale': 'Lagaf’ crew is similar to Zouaves Paris.'}
# CREATED REL: {'source': 'gargouilles', 'target': 'zouaves_paris', 'label': 'Similarity', 'rationale': 'Gargouilles is similar to Zouaves Paris.'}
# CREATED REL: {'source': 'zoulous_nice', 'target': 'zouaves_paris', 'label': 'Similarity', 'rationale': 'Zoulous Nice is similar to Zouaves Paris.'}
# Iteration ended at 2023-12-19 15:01:45.349715, duration: 0:00:17.207135
# FILE: starting to process ./llm_responses/article-1_chunk-1.json
# Iteration started at 2023-12-19 15:01:45.350449
# CREATED ACTOR: Kata fight club with DB ID 292
# RESOLVED ACTOR: Gud => Gud
# RESOLVED ACTOR: Génération identitaire => Génération identitaire
# RESOLVED ACTOR: Zouaves => Zouaves
# CREATED ACTOR: Rémi G. with DB ID 293
# CREATED ACTOR: Hervé Ryssen with DB ID 294
# RESOLVED ACTOR: Marc de Cacqueray => Marc de Cacqueray-Valmenier
# CREATED ACTOR: Loutres Gang with DB ID 295
# RESOLVED ACTOR: Auctorum => Auctorum
# RESOLVED ACTOR: Luminis => Luminis
# RESOLVED ACTOR: Academia Christiana => Academia Christiana
# CREATED REL: {'source': 'remi_g', 'target': 'gud', 'label': 'member of', 'rationale': 'Rémi G. is a member of Gud.'}
# CREATED REL: {'source': 'remi_g', 'target': 'academia_christiana', 'label': 'member of', 'rationale': 'Rémi G. is a member of Academia Christiana.'}
# CREATED REL: {'source': 'herve_ryssen', 'target': 'remi_g', 'label': 'content shared by', 'rationale': "Hervé Ryssen's documentaries are shared by Rémi G."}
# RESOLVED REL: {'source': 'marc_de_cacqueray', 'target': 'gud', 'label': 'leader of', 'rationale': 'Marc de Cacqueray is the leader of Gud.'} resolved to (115, 33, 19, 'leads', 'Marc de Cacqueray leads Gud.')
# CREATED REL: {'source': 'loutres_gang', 'target': 'auctorum', 'label': 'composed of', 'rationale': 'Loutres Gang is composed of members from Auctorum.'}
# CREATED REL: {'source': 'loutres_gang', 'target': 'luminis', 'label': 'composed of', 'rationale': 'Loutres Gang is composed of members from Luminis.'}
# Iteration ended at 2023-12-19 15:01:58.875840, duration: 0:00:13.525391
# FILE: starting to process ./llm_responses/article-2_chunk-3.json
# Iteration started at 2023-12-19 15:01:58.877218
# RESOLVED ACTOR: Pierre => Pierre C.
# RESOLVED ACTOR: Tristan C. => Tristan Conchon
# RESOLVED ACTOR: Gud => Gud
# CREATED ACTOR: DM with DB ID 296
# CREATED ACTOR: Titeuf with DB ID 297
# RESOLVED ACTOR: Division Martel => Martel division
# RESOLVED ACTOR: Vandal Besak de Besançon => Vandal Besak
# RESOLVED ACTOR: Korrigan Squad => Korrigans Squad
# CREATED ACTOR: Ouest Casual with DB ID 298
# CREATED ACTOR: Lenny M. with DB ID 299
# RESOLVED ACTOR: Nino => Nina Azamberti
# RESOLVED ACTOR: Marc de Cacqueray Valmenier => Marc de Cacqueray-Valmenier
# RESOLVED ACTOR: Comité du 9 mai => Comité du 9 mai
# RESOLVED ACTOR: Pierre C. => Pierre C.
# RESOLVED ACTOR: Louis N. => Louis N.
# CREATED REL: {'source': 'pierre', 'target': 'tristan_c', 'label': 'Collaboration', 'rationale': 'Pierre and Tristan C. are both members of the same radical right group and are involved in attacks together.'}
# CREATED REL: {'source': 'pierre', 'target': 'lenny_m', 'label': 'Collaboration', 'rationale': 'Pierre and Lenny M. are both members of the same radical right group and are involved in attacks together.'}
# CREATED REL: {'source': 'pierre', 'target': 'nino', 'label': 'Collaboration', 'rationale': 'Pierre and Nino are both members of the same radical right group and are involved in attacks together.'}
# CREATED REL: {'source': 'tristan_c', 'target': 'lenny_m', 'label': 'Collaboration', 'rationale': 'Tristan C. and Lenny M. are both members of the same radical right group and are involved in attacks together.'}
# CREATED REL: {'source': 'tristan_c', 'target': 'nino', 'label': 'Collaboration', 'rationale': 'Tristan C. and Nino are both members of the same radical right group and are involved in attacks together.'}
# CREATED REL: {'source': 'lenny_m', 'target': 'nino', 'label': 'Collaboration', 'rationale': 'Lenny M. and Nino are both members of the same radical right group and are involved in attacks together.'}
# RESOLVED REL: {'source': 'division_martel', 'target': 'vandal_besak_de_besancon', 'label': 'Collaboration', 'rationale': 'Division Martel has links with Vandal Besak de Besançon.'} resolved to (24, 26, 31, 'associated with', 'The Martel division has been seen with the Vandal Besak in Besançon.')
# RESOLVED REL: {'source': 'division_martel', 'target': 'korrigan_squad', 'label': 'Collaboration', 'rationale': 'Division Martel has links with Korrigan Squad.'} resolved to (25, 26, 32, 'associated with', 'The Martel division has been seen with the Korrigans Squad in Besançon.')
# CREATED REL: {'source': 'division_martel', 'target': 'ouest_casual', 'label': 'Collaboration', 'rationale': 'Division Martel uses Ouest Casual for communication.'}
# CREATED REL: {'source': 'division_martel', 'target': 'comite_du_9_mai', 'label': 'Collaboration', 'rationale': 'Division Martel is involved with Comité du 9 mai.'}
# CREATED REL: {'source': 'pierre_c', 'target': 'louis_n', 'label': 'Collaboration', 'rationale': 'Pierre C. and Louis N. are both members of the same radical right group and are involved in attacks together.'}
# Iteration ended at 2023-12-19 15:02:14.120011, duration: 0:00:15.242793
# FILE: starting to process ./llm_responses/article-6_chunk-1.json
# Iteration started at 2023-12-19 15:02:14.120527
# RESOLVED ACTOR: Martel division => Martel division
# Iteration ended at 2023-12-19 15:02:14.686875, duration: 0:00:00.566348
# FILE: starting to process ./llm_responses/article-2_chunk-2.json
# Iteration started at 2023-12-19 15:02:14.687276
# RESOLVED ACTOR: division Martel => Martel division
# RESOLVED ACTOR: Gud => Gud
# RESOLVED ACTOR: Zouaves Paris => Zouaves Paris
# CREATED ACTOR: frères Kléber with DB ID 300
# CREATED ACTOR: Hugo Vidal with DB ID 301
# RESOLVED ACTOR: Mathis D. => Mathis D.
# RESOLVED ACTOR: Léo R. => Léo R.
# RESOLVED ACTOR: Pierre => Pierre C.
# RESOLVED ACTOR: Tristan C. => Tristan Conchon
# RESOLVED ACTOR: Auctorum => Auctorum
# RESOLVED ACTOR: Luminis => Luminis
# RESOLVED ACTOR: Marc de Cacqueray-Valmenier => Marco J.
# RESOLVED ACTOR: Antoine => Antoine C.
# CREATED ACTOR: Jeunesse Boulogne with DB ID 302
# CREATED ACTOR: MesOs Reims with DB ID 303
# RESOLVED ACTOR: Pierre C. => Pierre C.
# RESOLVED ACTOR: Elie I. => Elie I.
# CREATED REL: {'source': 'division_martel', 'target': 'gud', 'label': 'is guided by', 'rationale': 'The division Martel is guided by the Gud.'}
# CREATED REL: {'source': 'gud', 'target': 'zouaves_paris', 'label': 'was reactivated by', 'rationale': 'The Gud was reactivated by the Zouaves Paris.'}
# CREATED REL: {'source': 'division_martel', 'target': 'freres_kleber', 'label': 'is a member of', 'rationale': 'The Kléber brothers are members of the Gud.'}
# CREATED REL: {'source': 'division_martel', 'target': 'hugo_vidal', 'label': 'is a member of', 'rationale': 'Hugo Vidal is a member of the Gud.'}
# RESOLVED REL: {'source': 'division_martel', 'target': 'mathis_d', 'label': 'is a member of', 'rationale': 'Mathis D. is a member of the division Martel and the Gud.'} resolved to (21, 26, 28, 'has member', 'The Martel division has Mathis D. as a member.')
# RESOLVED REL: {'source': 'division_martel', 'target': 'leo_r', 'label': 'is a member of', 'rationale': 'Léo R. is a member of the division Martel.'} resolved to (22, 26, 29, 'has member', 'The Martel division has Léo R. as a member.')
# RESOLVED REL: {'source': 'division_martel', 'target': 'pierre', 'label': 'is a member of', 'rationale': 'Pierre is a member of the division Martel.'} resolved to (18, 25, 26, 'member of', 'Pierre C. is a member of the Martel division.')
# CREATED REL: {'source': 'division_martel', 'target': 'tristan_c', 'label': 'is a member of', 'rationale': 'Tristan C. is a member of the division Martel.'}
# CREATED REL: {'source': 'division_martel', 'target': 'auctorum', 'label': "participated in a 'sports stage' with", 'rationale': "The division Martel participated in a 'sports stage' with Auctorum."}
# CREATED REL: {'source': 'division_martel', 'target': 'luminis', 'label': "participated in a 'sports stage' with", 'rationale': "The division Martel participated in a 'sports stage' with Luminis."}
# CREATED REL: {'source': 'gud', 'target': 'marc_de_cacquerayvalmenier', 'label': 'is led by', 'rationale': 'The Gud is led by Marc de Cacqueray-Valmenier.'}
# RESOLVED REL: {'source': 'division_martel', 'target': 'antoine', 'label': 'is a member of', 'rationale': 'Antoine is a member of the division Martel.'} resolved to (20, 26, 27, 'has member', 'The Martel division has Antoine C. as a member.')
# CREATED REL: {'source': 'division_martel', 'target': 'jeunesse_boulogne', 'label': 'hangs out with', 'rationale': 'The division Martel hangs out with Jeunesse Boulogne.'}
# CREATED REL: {'source': 'division_martel', 'target': 'mesos_reims', 'label': 'hangs out with', 'rationale': 'The division Martel hangs out with MesOs Reims.'}
# RESOLVED REL: {'source': 'division_martel', 'target': 'pierre_c', 'label': 'is a member of', 'rationale': 'Pierre C. is a member of the division Martel.'} resolved to (18, 25, 26, 'member of', 'Pierre C. is a member of the Martel division.')
# RESOLVED REL: {'source': 'division_martel', 'target': 'elie_i', 'label': 'is a member of', 'rationale': 'Elie I. is a member of the division Martel.'} resolved to (23, 26, 30, 'has member', 'The Martel division has Elie I. as a member.')
# Iteration ended at 2023-12-19 15:02:38.586537, duration: 0:00:23.899261
# FILE: starting to process ./llm_responses/article-5_chunk-2.json
# Iteration started at 2023-12-19 15:02:38.586892
# Iteration ended at 2023-12-19 15:02:38.588105, duration: 0:00:00.001213
# FILE: starting to process ./llm_responses/article-29_chunk-3.json
# Iteration started at 2023-12-19 15:02:38.588203
# Iteration ended at 2023-12-19 15:02:38.588613, duration: 0:00:00.000410
# FILE: starting to process ./llm_responses/article-38_chunk-1.json
# Iteration started at 2023-12-19 15:02:38.588694
# CREATED ACTOR: Elie Hatem with DB ID 304
# CREATED ACTOR: Jean-Marie Le Pen with DB ID 305
# RESOLVED ACTOR: Action Française => Action Française
# CREATED ACTOR: Konstantin Malofeev with DB ID 306
# RESOLVED ACTOR: Marine Le Pen => Marine Le Pen
# CREATED REL: {'source': 'elie_hatem', 'target': 'jeanmarie_le_pen', 'label': 'Associate of', 'rationale': 'Elie Hatem is a close associate of Jean-Marie Le Pen.'}
# CREATED REL: {'source': 'elie_hatem', 'target': 'action_francaise', 'label': 'Left', 'rationale': 'Elie Hatem left Action Française to found a rival royalist group.'}
# CREATED REL: {'source': 'elie_hatem', 'target': 'konstantin_malofeev', 'label': 'Posed with', 'rationale': 'Elie Hatem posed with Konstantin Malofeev.'}
# CREATED REL: {'source': 'konstantin_malofeev', 'target': 'marine_le_pen', 'label': 'Provided loans to', 'rationale': 'Konstantin Malofeev provided Russian loans to Marine Le Pen.'}
# Iteration ended at 2023-12-19 15:02:43.613675, duration: 0:00:05.024981

# %%
conn = sqlite3.connect("streetpress.db")
cursor = conn.cursor()    

query = "SELECT COUNT(*) FROM relationships"
cursor.execute(query)

# Fetch and print the results
print(cursor.fetchall())

# Close the connection
conn.close()
# Out:
# [(328,)]

# %%
display_table_sqlite("actors")
# Out:
# [(1, 'RNJ', 'ORGANIZATION', 'The RNJ is a radical youth organization that was relaunched in 2023./nThe RNJ organizes Forums for training and cohesion for its members and sympathizers./nThe RNJ has local sections, each with a responsible person.'), (2, 'Pierre-Romain Thionnet', 'PERSON', 'Pierre-Romain Thionnet is the head of the RNJ and the creator of the RNJ Forums./nHe has also held the position of national secretary at the Cocarde.'), (3, 'Aloys Vojinovic', 'PERSON', 'Aloys Vojinovic is a former member of the Zouaves Paris, a dissolved nazifying group, who attended a talk on the situation in Hungary at an RNJ Forum./nHe is known to some young RN leaders, including parliamentary attaché Luc Lahalle.'), (4, 'Eyquem Pons', 'PERSON', 'Eyquem Pons, also known as Etienne Cormier, is a cadre of Generation Identity who also attended a talk on the situation in Hungary at an RNJ Forum.'), (5, 'Luc Lahalle', 'PERSON', 'Luc Lahalle is a parliamentary attaché who often attends RNJ Forums and has been photographed with Aloys Vojinovic./nHe is the assistant of RN MEP Catherine Griset.'), (6, 'Catherine Griset', 'PERSON', 'Catherine Griset is an RN MEP whose assistant is Luc Lahalle.'), (7, 'Franck Allisio', 'PERSON', 'Franck Allisio is a local deputy who was invited to the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'), (8, 'Rafael F.', 'PERSON', 'Rafael F., also known as the militant pseudonym Raphaël Ayma, is the spokesperson for Tenesoun./nHe attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône.'), (9, 'Hélios C.', 'PERSON', "Hélios C. is a neofascist militant from Tenesoun who regularly hosts political 'spaces' on the social network Twitter-X./nHe attended the first Southern Forum organized by the RNJ of Bouches-du-Rhône."), (10, 'Nicolas M.', 'PERSON', "Nicolas M. is a militant who has been through the UNI and has been photographed in front of a 'Clément deserves' tag and a Celtic cross with some members of Tenesoun.")]

# %%
print(get_rel_by_id(vct_rel_index.search("The Martel division has Mathis D. as a member.")[0]))
# Out:
# (21, 20, 22, 'has member', 'The Martel division has Mathis D. as a member.')
